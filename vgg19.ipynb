# %% [markdown]
# <a href="https://colab.research.google.com/github/GopikaSravanthi/AI-Recruitment-Decision-Support-System/blob/main/vgg19.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Install specific versions of the libraries in Colab
# !pip install numpy==1.26.4 scipy==1.15.2 scikit-learn==1.6.1 lightgbm==4.6.0 catboost
# Out:
# Requirement already satisfied: numpy==1.26.4 in /usr/local/lib/python3.11/dist-packages (1.26.4)
# Requirement already satisfied: scipy==1.15.2 in /usr/local/lib/python3.11/dist-packages (1.15.2)
# Requirement already satisfied: scikit-learn==1.6.1 in /usr/local/lib/python3.11/dist-packages (1.6.1)
# Requirement already satisfied: lightgbm==4.6.0 in /usr/local/lib/python3.11/dist-packages (4.6.0)
# Requirement already satisfied: catboost in /usr/local/lib/python3.11/dist-packages (1.2.7)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn==1.6.1) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn==1.6.1) (3.6.0)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.11/dist-packages (from catboost) (0.20.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from catboost) (3.10.0)
# Requirement already satisfied: pandas>=0.24 in /usr/local/lib/python3.11/dist-packages (from catboost) (2.2.2)
# Requirement already satisfied: plotly in /usr/local/lib/python3.11/dist-packages (from catboost) (5.24.1)
# Requirement already satisfied: six in /usr/local/lib/python3.11/dist-packages (from catboost) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.24->catboost) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.24->catboost) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.24->catboost) (2025.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (3.2.1)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.11/dist-packages (from plotly->catboost) (9.0.0)

# %%
# !apt-get install -y cmake
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# cmake is already the newest version (3.22.1-1ubuntu1.22.04.2).
# 0 upgraded, 0 newly installed, 0 to remove and 29 not upgraded.

# %%
import numpy as np
import scipy
import sklearn
import catboost
import lightgbm

# Print versions to ensure they are correct
print("NumPy version:", np.__version__)
print("SciPy version:", scipy.__version__)
print("Scikit-Learn version:", sklearn.__version__)
print("CatBoost version:", catboost.__version__)
print("LightGBM version:", lightgbm.__version__)
# Out:
# NumPy version: 1.26.4
# SciPy version: 1.15.2
# Scikit-Learn version: 1.6.1
# CatBoost version: 1.2.7
# LightGBM version: 4.6.0

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
zip_path = "/content/drive/My Drive/archive.zip"

if os.path.exists(zip_path):
    print("✅ Zip file found! Proceeding with extraction.")
else:
    print("❌ Zip file NOT found! Check the path.")
# Out:
# ✅ Zip file found! Proceeding with extraction.

# %%
import zipfile

extract_path = "/content/dataset"

# Extract the zip file
with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

print("✅ Dataset extracted successfully!")
print("Extracted files:", os.listdir(extract_path))
# Out:
# ✅ Dataset extracted successfully!
# Extracted files: ['imgs', 'driver_imgs_list.csv', 'sample_submission.csv']

# %%
import os
import pandas as pd

# Define extract_path (Make sure this variable is set correctly)
extract_path = "/content/dataset"  # Change this to your actual path

# Load the CSV file
csv_path = os.path.join(extract_path, "driver_imgs_list.csv")
df = pd.read_csv(csv_path)

# Display first few rows
print(df.head())
# Out:
#   subject classname            img
# 0    p012        c0  img_10206.jpg
# 1    p012        c0  img_27079.jpg
# 2    p012        c0  img_50749.jpg
# 3    p012        c0  img_97089.jpg
# 4    p012        c0  img_37741.jpg

# %%
# Import required libraries
import os
import zipfile
import pandas as pd
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from google.colab import drive

# Step 1: Mount Google Drive
drive.mount('/content/drive')

# Step 2: Define dataset path in Google Drive
zip_path = "/content/drive/My Drive/archive.zip"  # Update if needed
extract_path = "/content/dataset"

# Step 3: Extract the zip file
with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

print("✅ Dataset extracted successfully!")

# Step 4: Define paths
train_dir = os.path.join(extract_path, "imgs", "train")
csv_path = os.path.join(extract_path, "driver_imgs_list.csv")

# Step 5: Load CSV File (Check driver image labels)
df = pd.read_csv(csv_path)
print(df.head())

# Step 6: Use ImageDataGenerator to Load Images in Batches (No RAM Overload)
IMG_SIZE = (224, 224)  # Resize images
BATCH_SIZE = 32  # Load images in small batches

# Data Generator for Training and Validation
datagen = ImageDataGenerator(rescale=1./255, validation_split=0.2)

train_generator = datagen.flow_from_directory(
    train_dir,
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    subset='training'  # 80% training
)

val_generator = datagen.flow_from_directory(
    train_dir,
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    subset='validation'  # 20% validation
)

print("✅ Data Generators Ready!")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ✅ Dataset extracted successfully!
#   subject classname            img
# 0    p012        c0  img_10206.jpg
# 1    p012        c0  img_27079.jpg
# 2    p012        c0  img_50749.jpg
# 3    p012        c0  img_97089.jpg
# 4    p012        c0  img_37741.jpg
# Found 13975 images belonging to 10 classes.
# Found 3487 images belonging to 10 classes.
# ✅ Data Generators Ready!

# %%
# !ls -R "/content/dataset"
# Out:
# /content/dataset:
# driver_imgs_list.csv  imgs  sample_submission.csv
#
# /content/dataset/imgs:
# test  train
#
# /content/dataset/imgs/test:
# img_100015.jpg	img_2388.jpg   img_39046.jpg  img_5356.jpg   img_68961.jpg  img_84735.jpg
# img_100027.jpg	img_23911.jpg  img_39052.jpg  img_53570.jpg  img_68974.jpg  img_84745.jpg
# img_100046.jpg	img_23917.jpg  img_39059.jpg  img_53609.jpg  img_68989.jpg  img_84752.jpg
# img_100057.jpg	img_23932.jpg  img_3906.jpg   img_53621.jpg  img_6899.jpg   img_84776.jpg
# img_100061.jpg	img_23966.jpg  img_39097.jpg  img_5362.jpg   img_69003.jpg  img_84810.jpg
# img_100108.jpg	img_2398.jpg   img_39099.jpg  img_53650.jpg  img_69034.jpg  img_8482.jpg
# img_100113.jpg	img_23996.jpg  img_39110.jpg  img_53664.jpg  img_69053.jpg  img_84843.jpg
# img_100116.jpg	img_24009.jpg  img_39113.jpg  img_53667.jpg  img_69059.jpg  img_84899.jpg
# img_10012.jpg	img_24010.jpg  img_39114.jpg  img_53697.jpg  img_69061.jpg  img_84934.jpg
# img_100168.jpg	img_24017.jpg  img_39118.jpg  img_53713.jpg  img_69083.jpg  img_84935.jpg
# img_100201.jpg	img_24021.jpg  img_39144.jpg  img_53728.jpg  img_69088.jpg  img_84978.jpg
# img_100225.jpg	img_24022.jpg  img_39145.jpg  img_53740.jpg  img_69090.jpg  img_84984.jpg
# img_100232.jpg	img_24023.jpg  img_39154.jpg  img_53768.jpg  img_69092.jpg  img_84986.jpg
# img_100246.jpg	img_24038.jpg  img_39224.jpg  img_53777.jpg  img_69094.jpg  img_84987.jpg
# img_10025.jpg	img_24046.jpg  img_39245.jpg  img_53788.jpg  img_69113.jpg  img_85043.jpg
# img_100299.jpg	img_24057.jpg  img_39260.jpg  img_53796.jpg  img_69130.jpg  img_85053.jpg
# img_100312.jpg	img_2409.jpg   img_39268.jpg  img_53824.jpg  img_6916.jpg   img_85095.jpg
# img_100314.jpg	img_24152.jpg  img_392.jpg    img_53825.jpg  img_69182.jpg  img_85101.jpg
# img_100327.jpg	img_24170.jpg  img_39313.jpg  img_53852.jpg  img_69211.jpg  img_85121.jpg
# img_100343.jpg	img_24238.jpg  img_39317.jpg  img_53853.jpg  img_69281.jpg  img_85127.jpg
# img_10034.jpg	img_24240.jpg  img_39324.jpg  img_53889.jpg  img_69323.jpg  img_85138.jpg
# img_100365.jpg	img_24247.jpg  img_39351.jpg  img_53901.jpg  img_69376.jpg  img_85165.jpg
# img_100403.jpg	img_24254.jpg  img_39355.jpg  img_53913.jpg  img_69407.jpg  img_85169.jpg
# img_100419.jpg	img_24255.jpg  img_39356.jpg  img_53916.jpg  img_69408.jpg  img_85173.jpg
# img_100423.jpg	img_24277.jpg  img_39358.jpg  img_53920.jpg  img_69412.jpg  img_8520.jpg
# img_100458.jpg	img_24286.jpg  img_39371.jpg  img_5396.jpg   img_69428.jpg  img_85210.jpg
# img_100480.jpg	img_24306.jpg  img_39373.jpg  img_54004.jpg  img_69477.jpg  img_85224.jpg
# img_100515.jpg	img_24315.jpg  img_39386.jpg  img_54086.jpg  img_69498.jpg  img_85240.jpg
# img_100528.jpg	img_24368.jpg  img_39400.jpg  img_5410.jpg   img_69540.jpg  img_85272.jpg
# img_100545.jpg	img_24370.jpg  img_39409.jpg  img_54158.jpg  img_69551.jpg  img_85282.jpg
# img_100548.jpg	img_24378.jpg  img_39422.jpg  img_54207.jpg  img_69565.jpg  img_85296.jpg
# img_1005.jpg	img_24379.jpg  img_39429.jpg  img_54212.jpg  img_69573.jpg  img_85299.jpg
# img_100638.jpg	img_24397.jpg  img_39465.jpg  img_54235.jpg  img_69578.jpg  img_85321.jpg
# img_100646.jpg	img_24457.jpg  img_39490.jpg  img_54238.jpg  img_69584.jpg  img_85335.jpg
# img_100682.jpg	img_24474.jpg  img_394.jpg    img_54278.jpg  img_69590.jpg  img_85346.jpg
# img_100683.jpg	img_24504.jpg  img_39507.jpg  img_54285.jpg  img_69592.jpg  img_85388.jpg
# img_100735.jpg	img_24508.jpg  img_39526.jpg  img_54317.jpg  img_69602.jpg  img_85411.jpg
# img_100738.jpg	img_24525.jpg  img_39577.jpg  img_54319.jpg  img_69607.jpg  img_85416.jpg
# img_100754.jpg	img_24547.jpg  img_39644.jpg  img_54320.jpg  img_69623.jpg  img_85428.jpg
# img_100777.jpg	img_24554.jpg  img_3965.jpg   img_54337.jpg  img_69636.jpg  img_85440.jpg
# img_100783.jpg	img_24561.jpg  img_3966.jpg   img_54366.jpg  img_69642.jpg  img_85445.jpg
# img_100846.jpg	img_24576.jpg  img_39670.jpg  img_54374.jpg  img_69663.jpg  img_85453.jpg
# img_100870.jpg	img_24621.jpg  img_3967.jpg   img_54407.jpg  img_69672.jpg  img_85478.jpg
# img_10090.jpg	img_2462.jpg   img_39728.jpg  img_54415.jpg  img_69692.jpg  img_85545.jpg
# img_100912.jpg	img_24670.jpg  img_39735.jpg  img_54444.jpg  img_69693.jpg  img_85546.jpg
# img_100913.jpg	img_24690.jpg  img_39754.jpg  img_54453.jpg  img_69694.jpg  img_85586.jpg
# img_10094.jpg	img_24704.jpg  img_39755.jpg  img_54487.jpg  img_69710.jpg  img_85590.jpg
# img_100995.jpg	img_24715.jpg  img_39776.jpg  img_54488.jpg  img_69721.jpg  img_85610.jpg
# img_101016.jpg	img_24776.jpg  img_39787.jpg  img_5450.jpg   img_69722.jpg  img_85632.jpg
# img_101029.jpg	img_24781.jpg  img_39796.jpg  img_54518.jpg  img_69726.jpg  img_8564.jpg
# img_101035.jpg	img_24783.jpg  img_39809.jpg  img_5451.jpg   img_69741.jpg  img_85652.jpg
# img_101038.jpg	img_24818.jpg  img_39820.jpg  img_54541.jpg  img_69756.jpg  img_85672.jpg
# img_10103.jpg	img_24864.jpg  img_39821.jpg  img_54548.jpg  img_69790.jpg  img_85734.jpg
# img_101051.jpg	img_24875.jpg  img_39826.jpg  img_54560.jpg  img_69823.jpg  img_85765.jpg
# img_101097.jpg	img_24878.jpg  img_39861.jpg  img_54611.jpg  img_69828.jpg  img_8576.jpg
# img_101134.jpg	img_24893.jpg  img_39868.jpg  img_54614.jpg  img_69860.jpg  img_857.jpg
# img_101159.jpg	img_24905.jpg  img_39900.jpg  img_54617.jpg  img_69861.jpg  img_8580.jpg
# img_101163.jpg	img_24917.jpg  img_39938.jpg  img_54640.jpg  img_69900.jpg  img_85811.jpg
# img_10116.jpg	img_24927.jpg  img_39940.jpg  img_54649.jpg  img_69904.jpg  img_85830.jpg
# img_101195.jpg	img_24944.jpg  img_39944.jpg  img_54652.jpg  img_69940.jpg  img_85839.jpg
# img_101196.jpg	img_2494.jpg   img_39960.jpg  img_5465.jpg   img_69950.jpg  img_85849.jpg
# img_101258.jpg	img_24959.jpg  img_39966.jpg  img_54688.jpg  img_69971.jpg  img_85880.jpg
# img_101295.jpg	img_24984.jpg  img_39979.jpg  img_54689.jpg  img_69973.jpg  img_858.jpg
# img_101320.jpg	img_24991.jpg  img_39989.jpg  img_54690.jpg  img_69977.jpg  img_85906.jpg
# img_101364.jpg	img_2499.jpg   img_40012.jpg  img_54712.jpg  img_6.jpg	    img_85949.jpg
# img_10141.jpg	img_25001.jpg  img_40013.jpg  img_54734.jpg  img_70033.jpg  img_85958.jpg
# img_101449.jpg	img_25010.jpg  img_40022.jpg  img_54750.jpg  img_70050.jpg  img_85969.jpg
# img_101456.jpg	img_25017.jpg  img_4004.jpg   img_54759.jpg  img_70069.jpg  img_85979.jpg
# img_101476.jpg	img_25036.jpg  img_40050.jpg  img_54782.jpg  img_70071.jpg  img_86001.jpg
# img_101499.jpg	img_25061.jpg  img_40065.jpg  img_54810.jpg  img_70077.jpg  img_86005.jpg
# img_101505.jpg	img_25072.jpg  img_4006.jpg   img_54819.jpg  img_70091.jpg  img_86008.jpg
# img_101507.jpg	img_25094.jpg  img_40075.jpg  img_54829.jpg  img_70122.jpg  img_86032.jpg
# img_101513.jpg	img_2511.jpg   img_40093.jpg  img_54848.jpg  img_70124.jpg  img_8605.jpg
# img_101528.jpg	img_25160.jpg  img_40095.jpg  img_54886.jpg  img_70150.jpg  img_86087.jpg
# img_10156.jpg	img_25161.jpg  img_40126.jpg  img_54898.jpg  img_70207.jpg  img_860.jpg
# img_101575.jpg	img_25167.jpg  img_40127.jpg  img_54916.jpg  img_70220.jpg  img_86126.jpg
# img_101593.jpg	img_25187.jpg  img_40199.jpg  img_54950.jpg  img_70250.jpg  img_86171.jpg
# img_101610.jpg	img_25211.jpg  img_40205.jpg  img_54961.jpg  img_70260.jpg  img_86184.jpg
# img_101625.jpg	img_25224.jpg  img_40233.jpg  img_54974.jpg  img_70290.jpg  img_86189.jpg
# img_10164.jpg	img_25235.jpg  img_40239.jpg  img_55008.jpg  img_70328.jpg  img_86204.jpg
# img_101659.jpg	img_25255.jpg  img_40248.jpg  img_5503.jpg   img_70354.jpg  img_86211.jpg
# img_101668.jpg	img_25258.jpg  img_40249.jpg  img_55043.jpg  img_70363.jpg  img_86219.jpg
# img_10167.jpg	img_25260.jpg  img_40258.jpg  img_55047.jpg  img_70392.jpg  img_86222.jpg
# img_1016.jpg	img_2529.jpg   img_40278.jpg  img_55050.jpg  img_70402.jpg  img_86233.jpg
# img_101704.jpg	img_25317.jpg  img_40308.jpg  img_55108.jpg  img_70471.jpg  img_86250.jpg
# img_101713.jpg	img_2531.jpg   img_40321.jpg  img_55152.jpg  img_70478.jpg  img_86251.jpg
# img_101737.jpg	img_25337.jpg  img_40328.jpg  img_55176.jpg  img_70506.jpg  img_86261.jpg
# img_101776.jpg	img_25341.jpg  img_40332.jpg  img_55213.jpg  img_70510.jpg  img_86284.jpg
# img_101856.jpg	img_25361.jpg  img_4033.jpg   img_55214.jpg  img_70540.jpg  img_86303.jpg
# img_101898.jpg	img_25363.jpg  img_40367.jpg  img_55230.jpg  img_70547.jpg  img_86313.jpg
# img_101905.jpg	img_25389.jpg  img_40417.jpg  img_55264.jpg  img_70568.jpg  img_86358.jpg
# img_10191.jpg	img_2539.jpg   img_40445.jpg  img_55318.jpg  img_70587.jpg  img_8635.jpg
# img_101920.jpg	img_25460.jpg  img_40457.jpg  img_55325.jpg  img_70611.jpg  img_86383.jpg
# img_101921.jpg	img_25470.jpg  img_4045.jpg   img_55338.jpg  img_70622.jpg  img_86413.jpg
# img_10199.jpg	img_25477.jpg  img_40554.jpg  img_55376.jpg  img_70627.jpg  img_86479.jpg
# img_10202.jpg	img_25482.jpg  img_40557.jpg  img_55385.jpg  img_70644.jpg  img_86495.jpg
# img_102056.jpg	img_25489.jpg  img_40576.jpg  img_55398.jpg  img_70645.jpg  img_86509.jpg
# img_102083.jpg	img_25535.jpg  img_40600.jpg  img_55415.jpg  img_70649.jpg  img_86517.jpg
# img_102087.jpg	img_25545.jpg  img_40612.jpg  img_55432.jpg  img_70664.jpg  img_86539.jpg
# img_102095.jpg	img_25566.jpg  img_40621.jpg  img_5545.jpg   img_70675.jpg  img_86543.jpg
# img_102119.jpg	img_25600.jpg  img_4062.jpg   img_55461.jpg  img_70684.jpg  img_86549.jpg
# img_102128.jpg	img_25612.jpg  img_40633.jpg  img_55482.jpg  img_70712.jpg  img_86599.jpg
# img_102138.jpg	img_25635.jpg  img_40645.jpg  img_55510.jpg  img_70718.jpg  img_86613.jpg
# img_10277.jpg	img_25670.jpg  img_40652.jpg  img_5553.jpg   img_70729.jpg  img_86615.jpg
# img_10307.jpg	img_25697.jpg  img_40697.jpg  img_55578.jpg  img_70732.jpg  img_86648.jpg
# img_10327.jpg	img_25712.jpg  img_40712.jpg  img_55583.jpg  img_70753.jpg  img_8670.jpg
# img_10349.jpg	img_2575.jpg   img_40733.jpg  img_555.jpg    img_7075.jpg   img_86725.jpg
# img_10359.jpg	img_25767.jpg  img_40763.jpg  img_55604.jpg  img_70787.jpg  img_86743.jpg
# img_10406.jpg	img_25770.jpg  img_40778.jpg  img_55675.jpg  img_70795.jpg  img_86778.jpg
# img_10422.jpg	img_25815.jpg  img_40799.jpg  img_55683.jpg  img_7080.jpg   img_86854.jpg
# img_10473.jpg	img_25818.jpg  img_4083.jpg   img_55755.jpg  img_70831.jpg  img_86888.jpg
# img_10514.jpg	img_2583.jpg   img_40857.jpg  img_55791.jpg  img_70846.jpg  img_86913.jpg
# img_10550.jpg	img_25847.jpg  img_4087.jpg   img_55795.jpg  img_70870.jpg  img_86921.jpg
# img_10564.jpg	img_25850.jpg  img_4090.jpg   img_557.jpg    img_70907.jpg  img_86953.jpg
# img_10606.jpg	img_25851.jpg  img_40911.jpg  img_55810.jpg  img_70934.jpg  img_86958.jpg
# img_10607.jpg	img_25861.jpg  img_40927.jpg  img_55817.jpg  img_70939.jpg  img_86967.jpg
# img_10620.jpg	img_25862.jpg  img_40930.jpg  img_55848.jpg  img_70946.jpg  img_86991.jpg
# img_10626.jpg	img_25864.jpg  img_40931.jpg  img_55853.jpg  img_70997.jpg  img_86992.jpg
# img_10627.jpg	img_2589.jpg   img_40944.jpg  img_5585.jpg   img_71006.jpg  img_87016.jpg
# img_1062.jpg	img_258.jpg    img_40953.jpg  img_5586.jpg   img_7101.jpg   img_87023.jpg
# img_10647.jpg	img_25911.jpg  img_40967.jpg  img_55881.jpg  img_71032.jpg  img_87043.jpg
# img_10698.jpg	img_25912.jpg  img_40976.jpg  img_55895.jpg  img_71059.jpg  img_87060.jpg
# img_10704.jpg	img_25913.jpg  img_40990.jpg  img_55898.jpg  img_71066.jpg  img_87081.jpg
# img_10758.jpg	img_25915.jpg  img_41017.jpg  img_55903.jpg  img_71077.jpg  img_87088.jpg
# img_10765.jpg	img_25921.jpg  img_41044.jpg  img_5590.jpg   img_71078.jpg  img_8708.jpg
# img_10768.jpg	img_25946.jpg  img_4105.jpg   img_55934.jpg  img_71085.jpg  img_87180.jpg
# img_10773.jpg	img_25949.jpg  img_4106.jpg   img_55938.jpg  img_71103.jpg  img_87182.jpg
# img_1078.jpg	img_25955.jpg  img_41084.jpg  img_5593.jpg   img_71104.jpg  img_87183.jpg
# img_10804.jpg	img_25980.jpg  img_41089.jpg  img_55953.jpg  img_71150.jpg  img_87230.jpg
# img_10812.jpg	img_25993.jpg  img_41096.jpg  img_55979.jpg  img_71169.jpg  img_87245.jpg
# img_10844.jpg	img_25998.jpg  img_41149.jpg  img_55985.jpg  img_711.jpg    img_87268.jpg
# img_10846.jpg	img_26043.jpg  img_41187.jpg  img_55992.jpg  img_71204.jpg  img_87273.jpg
# img_10847.jpg	img_26061.jpg  img_41191.jpg  img_55997.jpg  img_7122.jpg   img_87286.jpg
# img_10871.jpg	img_26067.jpg  img_41206.jpg  img_56031.jpg  img_71240.jpg  img_87301.jpg
# img_10919.jpg	img_26087.jpg  img_41236.jpg  img_56055.jpg  img_71243.jpg  img_87370.jpg
# img_10922.jpg	img_26094.jpg  img_41245.jpg  img_56058.jpg  img_71253.jpg  img_87373.jpg
# img_10939.jpg	img_26130.jpg  img_41251.jpg  img_5605.jpg   img_71265.jpg  img_8737.jpg
# img_10974.jpg	img_26136.jpg  img_41276.jpg  img_56073.jpg  img_71347.jpg  img_87387.jpg
# img_1098.jpg	img_2620.jpg   img_4128.jpg   img_56093.jpg  img_71377.jpg  img_87416.jpg
# img_11003.jpg	img_26226.jpg  img_41336.jpg  img_56099.jpg  img_71381.jpg  img_87423.jpg
# img_11018.jpg	img_26231.jpg  img_41349.jpg  img_56116.jpg  img_71388.jpg  img_87435.jpg
# img_1104.jpg	img_26246.jpg  img_41351.jpg  img_56123.jpg  img_71390.jpg  img_8744.jpg
# img_11052.jpg	img_26271.jpg  img_41357.jpg  img_56129.jpg  img_71404.jpg  img_87470.jpg
# img_11053.jpg	img_26293.jpg  img_41361.jpg  img_56147.jpg  img_71463.jpg  img_87484.jpg
# img_11061.jpg	img_26317.jpg  img_41406.jpg  img_56171.jpg  img_71478.jpg  img_87498.jpg
# img_11071.jpg	img_26330.jpg  img_41409.jpg  img_56202.jpg  img_71483.jpg  img_8749.jpg
# img_11120.jpg	img_26337.jpg  img_41412.jpg  img_56244.jpg  img_71504.jpg  img_87520.jpg
# img_1113.jpg	img_26355.jpg  img_41432.jpg  img_56251.jpg  img_71529.jpg  img_87534.jpg
# img_11144.jpg	img_26379.jpg  img_41473.jpg  img_56272.jpg  img_71538.jpg  img_87547.jpg
# img_11145.jpg	img_26392.jpg  img_4147.jpg   img_56274.jpg  img_71544.jpg  img_87575.jpg
# img_11177.jpg	img_2640.jpg   img_41498.jpg  img_56276.jpg  img_71589.jpg  img_87588.jpg
# img_11197.jpg	img_2645.jpg   img_41503.jpg  img_5627.jpg   img_71661.jpg  img_87607.jpg
# img_11228.jpg	img_2648.jpg   img_41576.jpg  img_562.jpg    img_71703.jpg  img_8764.jpg
# img_11230.jpg	img_26495.jpg  img_41582.jpg  img_56334.jpg  img_71718.jpg  img_87714.jpg
# img_11237.jpg	img_26515.jpg  img_41584.jpg  img_56346.jpg  img_71726.jpg  img_8771.jpg
# img_11257.jpg	img_26519.jpg  img_4158.jpg   img_56350.jpg  img_7172.jpg   img_87734.jpg
# img_11294.jpg	img_26559.jpg  img_41592.jpg  img_56370.jpg  img_71803.jpg  img_87789.jpg
# img_11328.jpg	img_26592.jpg  img_41597.jpg  img_56373.jpg  img_71811.jpg  img_8778.jpg
# img_1138.jpg	img_26602.jpg  img_41628.jpg  img_56396.jpg  img_71818.jpg  img_87797.jpg
# img_11416.jpg	img_26622.jpg  img_4162.jpg   img_56440.jpg  img_71864.jpg  img_87799.jpg
# img_1145.jpg	img_26639.jpg  img_41637.jpg  img_56467.jpg  img_7186.jpg   img_87808.jpg
# img_11478.jpg	img_26684.jpg  img_41648.jpg  img_56491.jpg  img_71872.jpg  img_87813.jpg
# img_11484.jpg	img_26701.jpg  img_41665.jpg  img_56494.jpg  img_71882.jpg  img_87829.jpg
# img_11526.jpg	img_26718.jpg  img_41670.jpg  img_56524.jpg  img_71904.jpg  img_87868.jpg
# img_11529.jpg	img_26722.jpg  img_41693.jpg  img_56539.jpg  img_71906.jpg  img_87887.jpg
# img_11533.jpg	img_26736.jpg  img_41704.jpg  img_56552.jpg  img_71935.jpg  img_87889.jpg
# img_11536.jpg	img_26740.jpg  img_41715.jpg  img_56568.jpg  img_71939.jpg  img_87912.jpg
# img_1153.jpg	img_26767.jpg  img_41728.jpg  img_56577.jpg  img_71945.jpg  img_87929.jpg
# img_11540.jpg	img_26768.jpg  img_4175.jpg   img_56578.jpg  img_71971.jpg  img_87931.jpg
# img_11545.jpg	img_26790.jpg  img_41780.jpg  img_56581.jpg  img_71990.jpg  img_87937.jpg
# img_11582.jpg	img_26807.jpg  img_41781.jpg  img_56602.jpg  img_7203.jpg   img_87942.jpg
# img_11616.jpg	img_26841.jpg  img_41805.jpg  img_56611.jpg  img_72063.jpg  img_87951.jpg
# img_11674.jpg	img_26914.jpg  img_41807.jpg  img_56618.jpg  img_72085.jpg  img_87958.jpg
# img_11744.jpg	img_26915.jpg  img_41810.jpg  img_56634.jpg  img_72130.jpg  img_87968.jpg
# img_11769.jpg	img_26934.jpg  img_41824.jpg  img_56654.jpg  img_72153.jpg  img_87971.jpg
# img_11776.jpg	img_2693.jpg   img_41856.jpg  img_56669.jpg  img_7216.jpg   img_87978.jpg
# img_11781.jpg	img_26944.jpg  img_4186.jpg   img_56674.jpg  img_72174.jpg  img_87995.jpg
# img_11813.jpg	img_26948.jpg  img_41894.jpg  img_56695.jpg  img_72208.jpg  img_87999.jpg
# img_11830.jpg	img_26953.jpg  img_41901.jpg  img_56698.jpg  img_72279.jpg  img_88012.jpg
# img_11842.jpg	img_26985.jpg  img_41902.jpg  img_56717.jpg  img_7227.jpg   img_88045.jpg
# img_11850.jpg	img_26988.jpg  img_41903.jpg  img_56724.jpg  img_7228.jpg   img_88068.jpg
# img_11896.jpg	img_27011.jpg  img_41912.jpg  img_56734.jpg  img_72291.jpg  img_88084.jpg
# img_1191.jpg	img_27077.jpg  img_41917.jpg  img_56754.jpg  img_72300.jpg  img_88085.jpg
# img_11937.jpg	img_27083.jpg  img_41918.jpg  img_56760.jpg  img_72310.jpg  img_88106.jpg
# img_11976.jpg	img_27095.jpg  img_41927.jpg  img_56775.jpg  img_72355.jpg  img_88171.jpg
# img_11982.jpg	img_27124.jpg  img_41948.jpg  img_56798.jpg  img_72363.jpg  img_88174.jpg
# img_12001.jpg	img_27168.jpg  img_41961.jpg  img_56800.jpg  img_72384.jpg  img_8817.jpg
# img_12011.jpg	img_27199.jpg  img_41962.jpg  img_56804.jpg  img_72391.jpg  img_88183.jpg
# img_12041.jpg	img_271.jpg    img_41980.jpg  img_56830.jpg  img_72414.jpg  img_88197.jpg
# img_12053.jpg	img_27204.jpg  img_41984.jpg  img_56869.jpg  img_72432.jpg  img_88202.jpg
# img_1207.jpg	img_27259.jpg  img_4198.jpg   img_56899.jpg  img_72446.jpg  img_88211.jpg
# img_12151.jpg	img_27266.jpg  img_42001.jpg  img_568.jpg    img_72447.jpg  img_88237.jpg
# img_12163.jpg	img_27287.jpg  img_42010.jpg  img_56936.jpg  img_72476.jpg  img_88282.jpg
# img_12164.jpg	img_27295.jpg  img_42018.jpg  img_56937.jpg  img_72482.jpg  img_88316.jpg
# img_12181.jpg	img_27301.jpg  img_42024.jpg  img_57002.jpg  img_72495.jpg  img_88330.jpg
# img_12185.jpg	img_27307.jpg  img_42032.jpg  img_57008.jpg  img_72516.jpg  img_88359.jpg
# img_12231.jpg	img_2730.jpg   img_42039.jpg  img_57012.jpg  img_72540.jpg  img_88375.jpg
# img_12279.jpg	img_27315.jpg  img_42064.jpg  img_57030.jpg  img_7254.jpg   img_88409.jpg
# img_12283.jpg	img_27334.jpg  img_4207.jpg   img_57036.jpg  img_72563.jpg  img_88448.jpg
# img_12289.jpg	img_27386.jpg  img_42080.jpg  img_57124.jpg  img_72572.jpg  img_88458.jpg
# img_12293.jpg	img_27403.jpg  img_42085.jpg  img_57155.jpg  img_72579.jpg  img_88474.jpg
# img_12294.jpg	img_27414.jpg  img_42125.jpg  img_57214.jpg  img_72593.jpg  img_88494.jpg
# img_12301.jpg	img_2744.jpg   img_42126.jpg  img_57321.jpg  img_72621.jpg  img_88520.jpg
# img_12319.jpg	img_27484.jpg  img_42155.jpg  img_57324.jpg  img_72648.jpg  img_88541.jpg
# img_12324.jpg	img_27485.jpg  img_42169.jpg  img_57326.jpg  img_72670.jpg  img_88563.jpg
# img_12338.jpg	img_27520.jpg  img_4217.jpg   img_57333.jpg  img_72680.jpg  img_88564.jpg
# img_12346.jpg	img_27535.jpg  img_42196.jpg  img_57336.jpg  img_72681.jpg  img_88591.jpg
# img_12375.jpg	img_2757.jpg   img_42211.jpg  img_57345.jpg  img_72736.jpg  img_88603.jpg
# img_12376.jpg	img_27608.jpg  img_42214.jpg  img_57400.jpg  img_7276.jpg   img_8860.jpg
# img_12378.jpg	img_2764.jpg   img_42217.jpg  img_57418.jpg  img_72777.jpg  img_88671.jpg
# img_12390.jpg	img_27652.jpg  img_42232.jpg  img_57437.jpg  img_72786.jpg  img_8868.jpg
# img_12410.jpg	img_27653.jpg  img_42250.jpg  img_57439.jpg  img_72819.jpg  img_88690.jpg
# img_12412.jpg	img_27663.jpg  img_42266.jpg  img_57458.jpg  img_72824.jpg  img_88700.jpg
# img_12457.jpg	img_27689.jpg  img_42279.jpg  img_57460.jpg  img_72865.jpg  img_88703.jpg
# img_12479.jpg	img_27703.jpg  img_42290.jpg  img_57479.jpg  img_72872.jpg  img_88761.jpg
# img_12485.jpg	img_27707.jpg  img_42291.jpg  img_5749.jpg   img_72886.jpg  img_88780.jpg
# img_12537.jpg	img_2770.jpg   img_42292.jpg  img_57513.jpg  img_72897.jpg  img_88790.jpg
# img_12538.jpg	img_27728.jpg  img_42302.jpg  img_57565.jpg  img_72907.jpg  img_88794.jpg
# img_12557.jpg	img_2772.jpg   img_42317.jpg  img_57594.jpg  img_72913.jpg  img_88801.jpg
# img_125.jpg	img_27760.jpg  img_42325.jpg  img_57609.jpg  img_72914.jpg  img_88803.jpg
# img_12630.jpg	img_27765.jpg  img_42358.jpg  img_57618.jpg  img_72916.jpg  img_88806.jpg
# img_12633.jpg	img_27774.jpg  img_42362.jpg  img_57621.jpg  img_72963.jpg  img_88821.jpg
# img_12635.jpg	img_27832.jpg  img_42387.jpg  img_57625.jpg  img_72969.jpg  img_8883.jpg
# img_12644.jpg	img_27849.jpg  img_4239.jpg   img_57637.jpg  img_72999.jpg  img_88846.jpg
# img_12715.jpg	img_27859.jpg  img_42407.jpg  img_57656.jpg  img_72.jpg     img_8884.jpg
# img_12716.jpg	img_27867.jpg  img_42430.jpg  img_57707.jpg  img_7301.jpg   img_88852.jpg
# img_1273.jpg	img_27870.jpg  img_42509.jpg  img_5771.jpg   img_73034.jpg  img_88859.jpg
# img_12740.jpg	img_27875.jpg  img_42523.jpg  img_57739.jpg  img_73056.jpg  img_88863.jpg
# img_12763.jpg	img_27884.jpg  img_42547.jpg  img_57745.jpg  img_73068.jpg  img_88875.jpg
# img_1282.jpg	img_27958.jpg  img_42571.jpg  img_57777.jpg  img_7306.jpg   img_88886.jpg
# img_12848.jpg	img_28028.jpg  img_42600.jpg  img_57780.jpg  img_73132.jpg  img_88891.jpg
# img_12876.jpg	img_28043.jpg  img_42624.jpg  img_57786.jpg  img_73143.jpg  img_88895.jpg
# img_12886.jpg	img_28045.jpg  img_42661.jpg  img_57814.jpg  img_73153.jpg  img_88896.jpg
# img_1290.jpg	img_28079.jpg  img_42731.jpg  img_57833.jpg  img_73160.jpg  img_88919.jpg
# img_12961.jpg	img_28106.jpg  img_42736.jpg  img_57835.jpg  img_73162.jpg  img_88930.jpg
# img_12978.jpg	img_2810.jpg   img_42753.jpg  img_57868.jpg  img_73164.jpg  img_88948.jpg
# img_13006.jpg	img_28131.jpg  img_4287.jpg   img_57877.jpg  img_7317.jpg   img_88956.jpg
# img_13022.jpg	img_28146.jpg  img_42881.jpg  img_57881.jpg  img_73192.jpg  img_8901.jpg
# img_13026.jpg	img_28169.jpg  img_42895.jpg  img_57898.jpg  img_73197.jpg  img_89021.jpg
# img_13044.jpg	img_28206.jpg  img_42913.jpg  img_57904.jpg  img_73215.jpg  img_89032.jpg
# img_13073.jpg	img_28208.jpg  img_4292.jpg   img_57908.jpg  img_7322.jpg   img_89040.jpg
# img_13099.jpg	img_28231.jpg  img_42939.jpg  img_57969.jpg  img_73240.jpg  img_89051.jpg
# img_13137.jpg	img_28233.jpg  img_42941.jpg  img_5796.jpg   img_73265.jpg  img_89059.jpg
# img_13144.jpg	img_28257.jpg  img_42954.jpg  img_57988.jpg  img_7328.jpg   img_89101.jpg
# img_13160.jpg	img_28258.jpg  img_42960.jpg  img_57989.jpg  img_73295.jpg  img_89131.jpg
# img_13179.jpg	img_28277.jpg  img_42979.jpg  img_57996.jpg  img_73323.jpg  img_89165.jpg
# img_13188.jpg	img_28293.jpg  img_42985.jpg  img_58000.jpg  img_73349.jpg  img_89168.jpg
# img_13211.jpg	img_28308.jpg  img_43005.jpg  img_58013.jpg  img_73360.jpg  img_89186.jpg
# img_13221.jpg	img_28335.jpg  img_43020.jpg  img_58123.jpg  img_73378.jpg  img_89196.jpg
# img_13244.jpg	img_28392.jpg  img_43035.jpg  img_58135.jpg  img_73392.jpg  img_89203.jpg
# img_13252.jpg	img_28404.jpg  img_43040.jpg  img_58145.jpg  img_73420.jpg  img_89213.jpg
# img_1326.jpg	img_28406.jpg  img_43046.jpg  img_58147.jpg  img_7344.jpg   img_89257.jpg
# img_13314.jpg	img_28432.jpg  img_43052.jpg  img_58149.jpg  img_73463.jpg  img_89295.jpg
# img_13318.jpg	img_28463.jpg  img_43057.jpg  img_58175.jpg  img_73485.jpg  img_89342.jpg
# img_13326.jpg	img_28478.jpg  img_43079.jpg  img_58188.jpg  img_73507.jpg  img_89388.jpg
# img_13330.jpg	img_28494.jpg  img_43132.jpg  img_58247.jpg  img_73517.jpg  img_89403.jpg
# img_13389.jpg	img_28524.jpg  img_43152.jpg  img_58253.jpg  img_73578.jpg  img_89406.jpg
# img_13398.jpg	img_28539.jpg  img_43197.jpg  img_58282.jpg  img_73586.jpg  img_89445.jpg
# img_133.jpg	img_28543.jpg  img_43226.jpg  img_58289.jpg  img_73591.jpg  img_89455.jpg
# img_13405.jpg	img_28576.jpg  img_4327.jpg   img_58304.jpg  img_73619.jpg  img_89462.jpg
# img_13413.jpg	img_28578.jpg  img_43304.jpg  img_58311.jpg  img_73647.jpg  img_89464.jpg
# img_13422.jpg	img_28635.jpg  img_4330.jpg   img_58318.jpg  img_73663.jpg  img_89476.jpg
# img_13470.jpg	img_28639.jpg  img_43311.jpg  img_58380.jpg  img_73672.jpg  img_8954.jpg
# img_13547.jpg	img_28684.jpg  img_43316.jpg  img_5840.jpg   img_7367.jpg   img_89556.jpg
# img_13585.jpg	img_28686.jpg  img_43317.jpg  img_58411.jpg  img_73688.jpg  img_89562.jpg
# img_13599.jpg	img_2870.jpg   img_43348.jpg  img_58448.jpg  img_7368.jpg   img_89580.jpg
# img_13607.jpg	img_28711.jpg  img_4335.jpg   img_58452.jpg  img_73708.jpg  img_89586.jpg
# img_13613.jpg	img_28717.jpg  img_43363.jpg  img_58457.jpg  img_73734.jpg  img_89621.jpg
# img_13625.jpg	img_28718.jpg  img_43370.jpg  img_58464.jpg  img_73739.jpg  img_89630.jpg
# img_13664.jpg	img_28720.jpg  img_43398.jpg  img_58465.jpg  img_73789.jpg  img_89652.jpg
# img_13675.jpg	img_28755.jpg  img_43433.jpg  img_58467.jpg  img_73804.jpg  img_89665.jpg
# img_13740.jpg	img_28828.jpg  img_43444.jpg  img_5849.jpg   img_7380.jpg   img_8968.jpg
# img_1374.jpg	img_28891.jpg  img_4344.jpg   img_58506.jpg  img_73825.jpg  img_89709.jpg
# img_13840.jpg	img_28909.jpg  img_43466.jpg  img_58543.jpg  img_73861.jpg  img_89727.jpg
# img_13863.jpg	img_28935.jpg  img_43469.jpg  img_58551.jpg  img_73878.jpg  img_89740.jpg
# img_1388.jpg	img_28942.jpg  img_43482.jpg  img_58560.jpg  img_73923.jpg  img_89746.jpg
# img_13903.jpg	img_28945.jpg  img_43484.jpg  img_58563.jpg  img_73928.jpg  img_8976.jpg
# img_13907.jpg	img_28973.jpg  img_43509.jpg  img_58564.jpg  img_73957.jpg  img_89779.jpg
# img_13916.jpg	img_28974.jpg  img_43511.jpg  img_58578.jpg  img_73981.jpg  img_8987.jpg
# img_13918.jpg	img_28975.jpg  img_43516.jpg  img_58584.jpg  img_7398.jpg   img_89882.jpg
# img_13938.jpg	img_28985.jpg  img_43519.jpg  img_58594.jpg  img_73991.jpg  img_89886.jpg
# img_13952.jpg	img_28988.jpg  img_43564.jpg  img_58615.jpg  img_74003.jpg  img_89888.jpg
# img_13958.jpg	img_2902.jpg   img_43569.jpg  img_58630.jpg  img_74022.jpg  img_89912.jpg
# img_13964.jpg	img_29070.jpg  img_43580.jpg  img_58642.jpg  img_74065.jpg  img_89925.jpg
# img_13965.jpg	img_29105.jpg  img_43583.jpg  img_58671.jpg  img_74078.jpg  img_89928.jpg
# img_13973.jpg	img_2910.jpg   img_43590.jpg  img_58723.jpg  img_74115.jpg  img_89930.jpg
# img_13994.jpg	img_29136.jpg  img_43648.jpg  img_58724.jpg  img_74116.jpg  img_89931.jpg
# img_1399.jpg	img_29159.jpg  img_4365.jpg   img_58738.jpg  img_74133.jpg  img_89957.jpg
# img_139.jpg	img_29170.jpg  img_43682.jpg  img_58743.jpg  img_7415.jpg   img_8997.jpg
# img_14025.jpg	img_29194.jpg  img_43696.jpg  img_58770.jpg  img_74174.jpg  img_90006.jpg
# img_14031.jpg	img_29225.jpg  img_4369.jpg   img_5877.jpg   img_74193.jpg  img_90030.jpg
# img_14035.jpg	img_29229.jpg  img_4371.jpg   img_58787.jpg  img_74212.jpg  img_90036.jpg
# img_14042.jpg	img_29230.jpg  img_4372.jpg   img_58803.jpg  img_74250.jpg  img_90051.jpg
# img_14072.jpg	img_29245.jpg  img_43749.jpg  img_58816.jpg  img_74288.jpg  img_90077.jpg
# img_14081.jpg	img_29261.jpg  img_43779.jpg  img_58834.jpg  img_74289.jpg  img_90102.jpg
# img_14107.jpg	img_29284.jpg  img_43815.jpg  img_58837.jpg  img_74296.jpg  img_90109.jpg
# img_14118.jpg	img_2928.jpg   img_43834.jpg  img_58845.jpg  img_74308.jpg  img_90112.jpg
# img_14162.jpg	img_29321.jpg  img_43859.jpg  img_58870.jpg  img_74326.jpg  img_90114.jpg
# img_14166.jpg	img_29342.jpg  img_43860.jpg  img_58895.jpg  img_74403.jpg  img_90117.jpg
# img_14167.jpg	img_29357.jpg  img_43895.jpg  img_58919.jpg  img_74405.jpg  img_90127.jpg
# img_14169.jpg	img_29368.jpg  img_43930.jpg  img_58922.jpg  img_7440.jpg   img_90142.jpg
# img_14187.jpg	img_29372.jpg  img_43954.jpg  img_58958.jpg  img_74424.jpg  img_90158.jpg
# img_1420.jpg	img_29375.jpg  img_43955.jpg  img_58961.jpg  img_74430.jpg  img_90159.jpg
# img_14240.jpg	img_29388.jpg  img_43974.jpg  img_58979.jpg  img_74436.jpg  img_90163.jpg
# img_1424.jpg	img_29400.jpg  img_43997.jpg  img_59000.jpg  img_74442.jpg  img_90192.jpg
# img_14264.jpg	img_29403.jpg  img_44002.jpg  img_59016.jpg  img_74454.jpg  img_90231.jpg
# img_14278.jpg	img_29409.jpg  img_44004.jpg  img_59020.jpg  img_74516.jpg  img_90239.jpg
# img_14299.jpg	img_29411.jpg  img_44007.jpg  img_59027.jpg  img_74517.jpg  img_90272.jpg
# img_14320.jpg	img_29422.jpg  img_44011.jpg  img_59067.jpg  img_74530.jpg  img_90273.jpg
# img_14363.jpg	img_29432.jpg  img_4401.jpg   img_59077.jpg  img_74535.jpg  img_90275.jpg
# img_14370.jpg	img_29438.jpg  img_44028.jpg  img_59094.jpg  img_74540.jpg  img_90284.jpg
# img_14397.jpg	img_29483.jpg  img_4402.jpg   img_5910.jpg   img_74556.jpg  img_90310.jpg
# img_14410.jpg	img_29490.jpg  img_44031.jpg  img_59152.jpg  img_74558.jpg  img_90321.jpg
# img_14413.jpg	img_294.jpg    img_44050.jpg  img_59170.jpg  img_74571.jpg  img_90344.jpg
# img_14418.jpg	img_29536.jpg  img_44091.jpg  img_59189.jpg  img_74573.jpg  img_90360.jpg
# img_14428.jpg	img_29548.jpg  img_44114.jpg  img_59203.jpg  img_74576.jpg  img_90385.jpg
# img_1444.jpg	img_29551.jpg  img_44121.jpg  img_5921.jpg   img_74627.jpg  img_90386.jpg
# img_14459.jpg	img_2955.jpg   img_44157.jpg  img_59225.jpg  img_74632.jpg  img_90389.jpg
# img_14460.jpg	img_29561.jpg  img_44242.jpg  img_5924.jpg   img_74659.jpg  img_90398.jpg
# img_14494.jpg	img_29599.jpg  img_44260.jpg  img_59270.jpg  img_74697.jpg  img_90442.jpg
# img_14552.jpg	img_29630.jpg  img_44274.jpg  img_59276.jpg  img_7470.jpg   img_90443.jpg
# img_1455.jpg	img_29633.jpg  img_44299.jpg  img_59318.jpg  img_74732.jpg  img_90556.jpg
# img_1457.jpg	img_29656.jpg  img_44312.jpg  img_59338.jpg  img_74762.jpg  img_9057.jpg
# img_14671.jpg	img_29658.jpg  img_44314.jpg  img_59390.jpg  img_74771.jpg  img_90583.jpg
# img_1467.jpg	img_2967.jpg   img_44326.jpg  img_59403.jpg  img_74793.jpg  img_90603.jpg
# img_14680.jpg	img_29706.jpg  img_4434.jpg   img_5941.jpg   img_74801.jpg  img_90618.jpg
# img_14690.jpg	img_29730.jpg  img_44369.jpg  img_59426.jpg  img_74802.jpg  img_9061.jpg
# img_14700.jpg	img_29734.jpg  img_4440.jpg   img_59434.jpg  img_74805.jpg  img_90620.jpg
# img_1472.jpg	img_2975.jpg   img_44429.jpg  img_59437.jpg  img_74819.jpg  img_90621.jpg
# img_14783.jpg	img_29776.jpg  img_44430.jpg  img_59449.jpg  img_74829.jpg  img_90646.jpg
# img_14792.jpg	img_29828.jpg  img_44437.jpg  img_59455.jpg  img_7484.jpg   img_90680.jpg
# img_14810.jpg	img_29829.jpg  img_44440.jpg  img_59474.jpg  img_74900.jpg  img_90687.jpg
# img_14813.jpg	img_29844.jpg  img_4447.jpg   img_59499.jpg  img_74902.jpg  img_9070.jpg
# img_14851.jpg	img_29864.jpg  img_44500.jpg  img_59566.jpg  img_74918.jpg  img_90722.jpg
# img_14857.jpg	img_29911.jpg  img_4450.jpg   img_59598.jpg  img_7491.jpg   img_90732.jpg
# img_14873.jpg	img_29918.jpg  img_44510.jpg  img_5963.jpg   img_74961.jpg  img_90747.jpg
# img_14921.jpg	img_29962.jpg  img_44537.jpg  img_59654.jpg  img_74964.jpg  img_90814.jpg
# img_14932.jpg	img_29971.jpg  img_44540.jpg  img_59705.jpg  img_75003.jpg  img_90816.jpg
# img_14936.jpg	img_29974.jpg  img_44544.jpg  img_59706.jpg  img_75012.jpg  img_9082.jpg
# img_14949.jpg	img_29977.jpg  img_44549.jpg  img_59709.jpg  img_75034.jpg  img_9083.jpg
# img_14974.jpg	img_29988.jpg  img_44610.jpg  img_59737.jpg  img_75064.jpg  img_9084.jpg
# img_14978.jpg	img_2998.jpg   img_44627.jpg  img_59748.jpg  img_75070.jpg  img_90856.jpg
# img_14986.jpg	img_30031.jpg  img_44628.jpg  img_59755.jpg  img_75111.jpg  img_90865.jpg
# img_1498.jpg	img_30042.jpg  img_44634.jpg  img_59763.jpg  img_75152.jpg  img_90866.jpg
# img_14991.jpg	img_30056.jpg  img_4463.jpg   img_5978.jpg   img_75158.jpg  img_90874.jpg
# img_1504.jpg	img_30061.jpg  img_44652.jpg  img_59810.jpg  img_7516.jpg   img_908.jpg
# img_15052.jpg	img_3012.jpg   img_44669.jpg  img_59823.jpg  img_75175.jpg  img_90911.jpg
# img_15069.jpg	img_30131.jpg  img_44673.jpg  img_5984.jpg   img_7522.jpg   img_90939.jpg
# img_15117.jpg	img_30176.jpg  img_44716.jpg  img_59859.jpg  img_75260.jpg  img_90982.jpg
# img_15127.jpg	img_30189.jpg  img_44733.jpg  img_59868.jpg  img_75269.jpg  img_91009.jpg
# img_15201.jpg	img_30190.jpg  img_44737.jpg  img_59872.jpg  img_75294.jpg  img_91042.jpg
# img_15215.jpg	img_30205.jpg  img_44758.jpg  img_59880.jpg  img_7533.jpg   img_91058.jpg
# img_15219.jpg	img_30206.jpg  img_44764.jpg  img_59908.jpg  img_75380.jpg  img_91070.jpg
# img_1521.jpg	img_30212.jpg  img_44821.jpg  img_59928.jpg  img_75477.jpg  img_91124.jpg
# img_15221.jpg	img_3024.jpg   img_44833.jpg  img_59935.jpg  img_7549.jpg   img_91129.jpg
# img_1523.jpg	img_30258.jpg  img_4483.jpg   img_59949.jpg  img_75526.jpg  img_91132.jpg
# img_15240.jpg	img_30294.jpg  img_44851.jpg  img_59951.jpg  img_75559.jpg  img_91135.jpg
# img_15263.jpg	img_30310.jpg  img_44861.jpg  img_59964.jpg  img_75597.jpg  img_91141.jpg
# img_1532.jpg	img_30359.jpg  img_44869.jpg  img_599.jpg    img_75598.jpg  img_91158.jpg
# img_15331.jpg	img_30369.jpg  img_44870.jpg  img_6002.jpg   img_75645.jpg  img_91182.jpg
# img_15335.jpg	img_3037.jpg   img_448.jpg    img_60065.jpg  img_75656.jpg  img_91196.jpg
# img_15367.jpg	img_30400.jpg  img_45037.jpg  img_60072.jpg  img_7566.jpg   img_9121.jpg
# img_15426.jpg	img_30421.jpg  img_4505.jpg   img_60080.jpg  img_75672.jpg  img_91222.jpg
# img_1542.jpg	img_30426.jpg  img_45097.jpg  img_60098.jpg  img_7567.jpg   img_91255.jpg
# img_15436.jpg	img_30433.jpg  img_4510.jpg   img_60115.jpg  img_75687.jpg  img_91268.jpg
# img_15441.jpg	img_30435.jpg  img_4511.jpg   img_60124.jpg  img_7568.jpg   img_91271.jpg
# img_15501.jpg	img_30445.jpg  img_45122.jpg  img_60206.jpg  img_75716.jpg  img_91274.jpg
# img_15508.jpg	img_3044.jpg   img_45169.jpg  img_60226.jpg  img_75725.jpg  img_91285.jpg
# img_15520.jpg	img_30453.jpg  img_45195.jpg  img_60235.jpg  img_75743.jpg  img_91289.jpg
# img_1554.jpg	img_30461.jpg  img_4521.jpg   img_60260.jpg  img_75753.jpg  img_91306.jpg
# img_15557.jpg	img_30486.jpg  img_45228.jpg  img_60290.jpg  img_75763.jpg  img_91404.jpg
# img_15559.jpg	img_30491.jpg  img_45243.jpg  img_60298.jpg  img_75764.jpg  img_91414.jpg
# img_15562.jpg	img_30493.jpg  img_45245.jpg  img_602.jpg    img_75778.jpg  img_91418.jpg
# img_15565.jpg	img_30498.jpg  img_45276.jpg  img_60337.jpg  img_75786.jpg  img_91424.jpg
# img_15566.jpg	img_30528.jpg  img_45277.jpg  img_60343.jpg  img_75826.jpg  img_9144.jpg
# img_15617.jpg	img_30542.jpg  img_45285.jpg  img_60360.jpg  img_75830.jpg  img_91518.jpg
# img_1564.jpg	img_30591.jpg  img_45293.jpg  img_60364.jpg  img_75842.jpg  img_91538.jpg
# img_15655.jpg	img_30592.jpg  img_45294.jpg  img_60373.jpg  img_75886.jpg  img_91559.jpg
# img_15659.jpg	img_30646.jpg  img_452.jpg    img_60376.jpg  img_75887.jpg  img_91564.jpg
# img_1565.jpg	img_30656.jpg  img_45304.jpg  img_60378.jpg  img_7590.jpg   img_91566.jpg
# img_15716.jpg	img_30672.jpg  img_45321.jpg  img_60404.jpg  img_75944.jpg  img_9157.jpg
# img_15717.jpg	img_30683.jpg  img_45355.jpg  img_60408.jpg  img_75950.jpg  img_91606.jpg
# img_15738.jpg	img_30690.jpg  img_45361.jpg  img_60435.jpg  img_75985.jpg  img_91620.jpg
# img_15756.jpg	img_30765.jpg  img_45397.jpg  img_60454.jpg  img_76000.jpg  img_91624.jpg
# img_15780.jpg	img_3078.jpg   img_4541.jpg   img_60458.jpg  img_76008.jpg  img_9164.jpg
# img_15790.jpg	img_30844.jpg  img_45430.jpg  img_6045.jpg   img_76110.jpg  img_91658.jpg
# img_15876.jpg	img_30859.jpg  img_45468.jpg  img_60469.jpg  img_76133.jpg  img_91676.jpg
# img_15878.jpg	img_30892.jpg  img_45485.jpg  img_60554.jpg  img_76155.jpg  img_91707.jpg
# img_15889.jpg	img_30893.jpg  img_45487.jpg  img_60585.jpg  img_76180.jpg  img_91710.jpg
# img_15895.jpg	img_30910.jpg  img_45513.jpg  img_60600.jpg  img_761.jpg    img_91761.jpg
# img_15905.jpg	img_30929.jpg  img_45539.jpg  img_60603.jpg  img_7620.jpg   img_91769.jpg
# img_15916.jpg	img_30935.jpg  img_45559.jpg  img_60610.jpg  img_76212.jpg  img_91777.jpg
# img_15918.jpg	img_30954.jpg  img_45560.jpg  img_60621.jpg  img_76277.jpg  img_91788.jpg
# img_15947.jpg	img_30975.jpg  img_45571.jpg  img_60630.jpg  img_76278.jpg  img_91793.jpg
# img_1595.jpg	img_30987.jpg  img_45599.jpg  img_60735.jpg  img_76293.jpg  img_91804.jpg
# img_1602.jpg	img_31005.jpg  img_45609.jpg  img_60740.jpg  img_7629.jpg   img_91845.jpg
# img_16030.jpg	img_31041.jpg  img_4562.jpg   img_60764.jpg  img_76359.jpg  img_91875.jpg
# img_16046.jpg	img_31046.jpg  img_45673.jpg  img_60767.jpg  img_76395.jpg  img_91890.jpg
# img_16049.jpg	img_31070.jpg  img_45678.jpg  img_6078.jpg   img_76429.jpg  img_91914.jpg
# img_1605.jpg	img_31076.jpg  img_45690.jpg  img_60822.jpg  img_76450.jpg  img_91946.jpg
# img_16125.jpg	img_31081.jpg  img_45764.jpg  img_60847.jpg  img_76458.jpg  img_9194.jpg
# img_16138.jpg	img_31104.jpg  img_45785.jpg  img_60861.jpg  img_76552.jpg  img_91962.jpg
# img_16143.jpg	img_31110.jpg  img_4578.jpg   img_60868.jpg  img_76554.jpg  img_92014.jpg
# img_16149.jpg	img_31126.jpg  img_45833.jpg  img_60891.jpg  img_76565.jpg  img_92026.jpg
# img_16159.jpg	img_31131.jpg  img_45844.jpg  img_60899.jpg  img_76568.jpg  img_92033.jpg
# img_16169.jpg	img_31158.jpg  img_4591.jpg   img_60902.jpg  img_76573.jpg  img_92068.jpg
# img_16214.jpg	img_31239.jpg  img_45930.jpg  img_60927.jpg  img_76640.jpg  img_92079.jpg
# img_16218.jpg	img_31303.jpg  img_45938.jpg  img_60935.jpg  img_76677.jpg  img_92108.jpg
# img_16231.jpg	img_3131.jpg   img_45950.jpg  img_60945.jpg  img_76678.jpg  img_9212.jpg
# img_16245.jpg	img_31375.jpg  img_45994.jpg  img_6101.jpg   img_76723.jpg  img_92146.jpg
# img_16248.jpg	img_31406.jpg  img_46008.jpg  img_61052.jpg  img_76731.jpg  img_92164.jpg
# img_16255.jpg	img_31429.jpg  img_46011.jpg  img_61056.jpg  img_76754.jpg  img_92225.jpg
# img_16270.jpg	img_31439.jpg  img_46028.jpg  img_61066.jpg  img_76767.jpg  img_92233.jpg
# img_16283.jpg	img_31448.jpg  img_46039.jpg  img_61077.jpg  img_76773.jpg  img_92237.jpg
# img_16306.jpg	img_31450.jpg  img_46040.jpg  img_61108.jpg  img_76776.jpg  img_92250.jpg
# img_16326.jpg	img_31467.jpg  img_46068.jpg  img_61122.jpg  img_76845.jpg  img_92259.jpg
# img_16331.jpg	img_31469.jpg  img_46076.jpg  img_61154.jpg  img_76849.jpg  img_9225.jpg
# img_16382.jpg	img_31474.jpg  img_46117.jpg  img_61196.jpg  img_76902.jpg  img_92289.jpg
# img_16385.jpg	img_31479.jpg  img_46141.jpg  img_61208.jpg  img_76926.jpg  img_9230.jpg
# img_16411.jpg	img_31481.jpg  img_46158.jpg  img_61209.jpg  img_76958.jpg  img_9231.jpg
# img_16466.jpg	img_31492.jpg  img_46160.jpg  img_61235.jpg  img_76963.jpg  img_92329.jpg
# img_16491.jpg	img_31543.jpg  img_4617.jpg   img_61253.jpg  img_77015.jpg  img_9232.jpg
# img_16500.jpg	img_31547.jpg  img_46190.jpg  img_61275.jpg  img_77082.jpg  img_92366.jpg
# img_16521.jpg	img_31562.jpg  img_46198.jpg  img_612.jpg    img_77127.jpg  img_92374.jpg
# img_16526.jpg	img_31569.jpg  img_46217.jpg  img_61300.jpg  img_77139.jpg  img_92383.jpg
# img_16532.jpg	img_31617.jpg  img_46218.jpg  img_61313.jpg  img_77156.jpg  img_92385.jpg
# img_16550.jpg	img_31644.jpg  img_46234.jpg  img_61361.jpg  img_77158.jpg  img_92443.jpg
# img_16586.jpg	img_31676.jpg  img_46248.jpg  img_61366.jpg  img_77159.jpg  img_92450.jpg
# img_16601.jpg	img_31681.jpg  img_46280.jpg  img_61368.jpg  img_77160.jpg  img_92464.jpg
# img_16606.jpg	img_31692.jpg  img_46285.jpg  img_61378.jpg  img_77164.jpg  img_92483.jpg
# img_16635.jpg	img_31701.jpg  img_46374.jpg  img_61429.jpg  img_77167.jpg  img_92488.jpg
# img_16652.jpg	img_31714.jpg  img_46398.jpg  img_61441.jpg  img_77168.jpg  img_92491.jpg
# img_16663.jpg	img_31740.jpg  img_46409.jpg  img_61461.jpg  img_77184.jpg  img_92503.jpg
# img_16714.jpg	img_31755.jpg  img_4640.jpg   img_61485.jpg  img_77189.jpg  img_92519.jpg
# img_1671.jpg	img_31757.jpg  img_46440.jpg  img_61515.jpg  img_77209.jpg  img_9253.jpg
# img_16728.jpg	img_31768.jpg  img_46464.jpg  img_61521.jpg  img_7720.jpg   img_92582.jpg
# img_16740.jpg	img_31778.jpg  img_46472.jpg  img_61563.jpg  img_77259.jpg  img_92625.jpg
# img_16755.jpg	img_3180.jpg   img_46496.jpg  img_61578.jpg  img_77266.jpg  img_92627.jpg
# img_16823.jpg	img_31811.jpg  img_46497.jpg  img_61624.jpg  img_77268.jpg  img_92629.jpg
# img_16831.jpg	img_31822.jpg  img_46518.jpg  img_61629.jpg  img_77289.jpg  img_92645.jpg
# img_16853.jpg	img_3182.jpg   img_46523.jpg  img_61631.jpg  img_77290.jpg  img_92674.jpg
# img_16856.jpg	img_31830.jpg  img_46525.jpg  img_61632.jpg  img_77299.jpg  img_92682.jpg
# img_16861.jpg	img_31856.jpg  img_46589.jpg  img_61660.jpg  img_77309.jpg  img_92692.jpg
# img_16866.jpg	img_31883.jpg  img_46603.jpg  img_61663.jpg  img_77356.jpg  img_92697.jpg
# img_16886.jpg	img_31888.jpg  img_46619.jpg  img_61672.jpg  img_77368.jpg  img_92701.jpg
# img_16904.jpg	img_31912.jpg  img_46632.jpg  img_61717.jpg  img_77376.jpg  img_92704.jpg
# img_16915.jpg	img_31913.jpg  img_46644.jpg  img_6171.jpg   img_77385.jpg  img_9270.jpg
# img_16925.jpg	img_31937.jpg  img_46648.jpg  img_61738.jpg  img_77409.jpg  img_9271.jpg
# img_16935.jpg	img_31943.jpg  img_4664.jpg   img_61739.jpg  img_77421.jpg  img_92750.jpg
# img_16990.jpg	img_31951.jpg  img_46650.jpg  img_61758.jpg  img_77443.jpg  img_92760.jpg
# img_17002.jpg	img_3196.jpg   img_46654.jpg  img_61778.jpg  img_77484.jpg  img_9276.jpg
# img_17022.jpg	img_32012.jpg  img_46686.jpg  img_61788.jpg  img_77489.jpg  img_92779.jpg
# img_1702.jpg	img_32021.jpg  img_46735.jpg  img_61790.jpg  img_77499.jpg  img_92785.jpg
# img_1703.jpg	img_32025.jpg  img_4676.jpg   img_61800.jpg  img_77515.jpg  img_92790.jpg
# img_17107.jpg	img_32055.jpg  img_46808.jpg  img_61806.jpg  img_77547.jpg  img_92814.jpg
# img_17120.jpg	img_32056.jpg  img_46832.jpg  img_61865.jpg  img_77562.jpg  img_92816.jpg
# img_17132.jpg	img_32081.jpg  img_46839.jpg  img_61914.jpg  img_77583.jpg  img_92823.jpg
# img_17174.jpg	img_32115.jpg  img_4684.jpg   img_61941.jpg  img_77586.jpg  img_92826.jpg
# img_17195.jpg	img_32131.jpg  img_46867.jpg  img_61942.jpg  img_77591.jpg  img_92857.jpg
# img_17218.jpg	img_32165.jpg  img_46872.jpg  img_62011.jpg  img_77599.jpg  img_92894.jpg
# img_1722.jpg	img_32174.jpg  img_46877.jpg  img_62012.jpg  img_775.jpg    img_92896.jpg
# img_17239.jpg	img_32186.jpg  img_46908.jpg  img_62022.jpg  img_77617.jpg  img_92935.jpg
# img_17250.jpg	img_32208.jpg  img_46939.jpg  img_62031.jpg  img_77658.jpg  img_92936.jpg
# img_17268.jpg	img_32209.jpg  img_46997.jpg  img_62048.jpg  img_77718.jpg  img_92952.jpg
# img_17270.jpg	img_32249.jpg  img_47017.jpg  img_62069.jpg  img_77730.jpg  img_92980.jpg
# img_17322.jpg	img_32355.jpg  img_47020.jpg  img_62076.jpg  img_77735.jpg  img_93004.jpg
# img_17359.jpg	img_32391.jpg  img_47057.jpg  img_62083.jpg  img_77747.jpg  img_93005.jpg
# img_17369.jpg	img_32392.jpg  img_47068.jpg  img_62095.jpg  img_7776.jpg   img_93036.jpg
# img_17388.jpg	img_32439.jpg  img_47106.jpg  img_62101.jpg  img_77780.jpg  img_93092.jpg
# img_17429.jpg	img_32455.jpg  img_47121.jpg  img_62110.jpg  img_77831.jpg  img_93094.jpg
# img_17449.jpg	img_32474.jpg  img_47177.jpg  img_6211.jpg   img_77863.jpg  img_93098.jpg
# img_17454.jpg	img_32490.jpg  img_47191.jpg  img_62125.jpg  img_77877.jpg  img_93115.jpg
# img_1746.jpg	img_32491.jpg  img_47215.jpg  img_62126.jpg  img_77889.jpg  img_93131.jpg
# img_17513.jpg	img_32500.jpg  img_4721.jpg   img_6212.jpg   img_77895.jpg  img_93138.jpg
# img_1752.jpg	img_32509.jpg  img_47225.jpg  img_62163.jpg  img_77903.jpg  img_93142.jpg
# img_17535.jpg	img_32510.jpg  img_47226.jpg  img_62168.jpg  img_77948.jpg  img_93212.jpg
# img_17546.jpg	img_32516.jpg  img_47230.jpg  img_62176.jpg  img_77950.jpg  img_93285.jpg
# img_17550.jpg	img_32524.jpg  img_47237.jpg  img_6220.jpg   img_77964.jpg  img_93319.jpg
# img_17571.jpg	img_32525.jpg  img_47254.jpg  img_62344.jpg  img_77970.jpg  img_93323.jpg
# img_17594.jpg	img_32542.jpg  img_47259.jpg  img_62383.jpg  img_78019.jpg  img_93373.jpg
# img_1759.jpg	img_32553.jpg  img_47265.jpg  img_623.jpg    img_78032.jpg  img_93382.jpg
# img_1760.jpg	img_32554.jpg  img_47284.jpg  img_62412.jpg  img_78034.jpg  img_93401.jpg
# img_17648.jpg	img_32558.jpg  img_47295.jpg  img_6241.jpg   img_78058.jpg  img_93416.jpg
# img_17668.jpg	img_32594.jpg  img_47320.jpg  img_62421.jpg  img_78068.jpg  img_93422.jpg
# img_17682.jpg	img_32614.jpg  img_47321.jpg  img_62433.jpg  img_78086.jpg  img_93438.jpg
# img_17696.jpg	img_3263.jpg   img_47322.jpg  img_62439.jpg  img_78091.jpg  img_93442.jpg
# img_17741.jpg	img_32667.jpg  img_4733.jpg   img_62513.jpg  img_78105.jpg  img_93468.jpg
# img_17772.jpg	img_32687.jpg  img_47349.jpg  img_62530.jpg  img_78126.jpg  img_93519.jpg
# img_17773.jpg	img_32701.jpg  img_47368.jpg  img_62551.jpg  img_78202.jpg  img_9352.jpg
# img_17794.jpg	img_32707.jpg  img_47377.jpg  img_62564.jpg  img_78240.jpg  img_93544.jpg
# img_17808.jpg	img_32714.jpg  img_47385.jpg  img_62656.jpg  img_78271.jpg  img_93554.jpg
# img_17812.jpg	img_32719.jpg  img_47393.jpg  img_62671.jpg  img_7828.jpg   img_93565.jpg
# img_17854.jpg	img_32792.jpg  img_47405.jpg  img_62698.jpg  img_78315.jpg  img_93609.jpg
# img_17871.jpg	img_32811.jpg  img_47407.jpg  img_62699.jpg  img_78319.jpg  img_93634.jpg
# img_17889.jpg	img_32823.jpg  img_47421.jpg  img_62737.jpg  img_7834.jpg   img_9364.jpg
# img_1790.jpg	img_32876.jpg  img_47447.jpg  img_62800.jpg  img_7837.jpg   img_93663.jpg
# img_17922.jpg	img_32899.jpg  img_4747.jpg   img_62804.jpg  img_78388.jpg  img_93704.jpg
# img_17948.jpg	img_32925.jpg  img_4748.jpg   img_62842.jpg  img_78405.jpg  img_93720.jpg
# img_17965.jpg	img_32934.jpg  img_47531.jpg  img_62871.jpg  img_78438.jpg  img_93725.jpg
# img_17990.jpg	img_32957.jpg  img_47536.jpg  img_62882.jpg  img_78518.jpg  img_93740.jpg
# img_17998.jpg	img_32967.jpg  img_47558.jpg  img_62894.jpg  img_78546.jpg  img_93756.jpg
# img_18051.jpg	img_32973.jpg  img_47604.jpg  img_62917.jpg  img_78549.jpg  img_93865.jpg
# img_18056.jpg	img_32982.jpg  img_47608.jpg  img_62930.jpg  img_78551.jpg  img_93872.jpg
# img_18066.jpg	img_32983.jpg  img_47629.jpg  img_62936.jpg  img_78561.jpg  img_93879.jpg
# img_18085.jpg	img_32990.jpg  img_47662.jpg  img_62946.jpg  img_78665.jpg  img_93894.jpg
# img_18091.jpg	img_32992.jpg  img_47712.jpg  img_62970.jpg  img_78710.jpg  img_93900.jpg
# img_18114.jpg	img_32998.jpg  img_47717.jpg  img_629.jpg    img_78744.jpg  img_93903.jpg
# img_18144.jpg	img_33007.jpg  img_47823.jpg  img_63004.jpg  img_7875.jpg   img_93904.jpg
# img_18155.jpg	img_33009.jpg  img_47847.jpg  img_6300.jpg   img_78761.jpg  img_93934.jpg
# img_18191.jpg	img_33011.jpg  img_47868.jpg  img_63015.jpg  img_78787.jpg  img_93978.jpg
# img_18198.jpg	img_33035.jpg  img_47882.jpg  img_63029.jpg  img_78827.jpg  img_94054.jpg
# img_18203.jpg	img_33045.jpg  img_47885.jpg  img_63035.jpg  img_78858.jpg  img_94078.jpg
# img_18240.jpg	img_33074.jpg  img_47888.jpg  img_63037.jpg  img_78936.jpg  img_94081.jpg
# img_18242.jpg	img_33103.jpg  img_47896.jpg  img_63062.jpg  img_78966.jpg  img_94088.jpg
# img_1830.jpg	img_33114.jpg  img_47911.jpg  img_63064.jpg  img_78996.jpg  img_94121.jpg
# img_18323.jpg	img_33126.jpg  img_47934.jpg  img_63077.jpg  img_79000.jpg  img_94140.jpg
# img_18345.jpg	img_33152.jpg  img_47986.jpg  img_63094.jpg  img_79002.jpg  img_94170.jpg
# img_18380.jpg	img_33166.jpg  img_47993.jpg  img_63126.jpg  img_79011.jpg  img_94182.jpg
# img_18407.jpg	img_33173.jpg  img_48026.jpg  img_63127.jpg  img_79017.jpg  img_94192.jpg
# img_18411.jpg	img_33184.jpg  img_48062.jpg  img_63135.jpg  img_79027.jpg  img_94215.jpg
# img_18412.jpg	img_33189.jpg  img_48068.jpg  img_6313.jpg   img_79050.jpg  img_94226.jpg
# img_18417.jpg	img_3320.jpg   img_48080.jpg  img_63190.jpg  img_79052.jpg  img_94253.jpg
# img_18424.jpg	img_33228.jpg  img_48083.jpg  img_63233.jpg  img_7907.jpg   img_9426.jpg
# img_18441.jpg	img_33258.jpg  img_48086.jpg  img_63234.jpg  img_79080.jpg  img_94277.jpg
# img_1844.jpg	img_33276.jpg  img_4809.jpg   img_63251.jpg  img_79087.jpg  img_94297.jpg
# img_18486.jpg	img_33277.jpg  img_48125.jpg  img_6326.jpg   img_7910.jpg   img_94304.jpg
# img_18516.jpg	img_33282.jpg  img_48175.jpg  img_6329.jpg   img_79142.jpg  img_94307.jpg
# img_18583.jpg	img_33292.jpg  img_48187.jpg  img_63308.jpg  img_7916.jpg   img_9430.jpg
# img_18585.jpg	img_33335.jpg  img_48210.jpg  img_63317.jpg  img_79195.jpg  img_94319.jpg
# img_18636.jpg	img_33368.jpg  img_48228.jpg  img_63318.jpg  img_79203.jpg  img_94352.jpg
# img_18673.jpg	img_33375.jpg  img_48252.jpg  img_63349.jpg  img_79226.jpg  img_94353.jpg
# img_18697.jpg	img_33383.jpg  img_48288.jpg  img_63355.jpg  img_79239.jpg  img_94386.jpg
# img_18709.jpg	img_33405.jpg  img_48323.jpg  img_63373.jpg  img_79286.jpg  img_94397.jpg
# img_18737.jpg	img_33450.jpg  img_48335.jpg  img_63401.jpg  img_79307.jpg  img_94437.jpg
# img_18753.jpg	img_33451.jpg  img_48339.jpg  img_63438.jpg  img_79318.jpg  img_94442.jpg
# img_18759.jpg	img_3345.jpg   img_48349.jpg  img_6346.jpg   img_79322.jpg  img_94475.jpg
# img_1875.jpg	img_33460.jpg  img_48353.jpg  img_63477.jpg  img_79327.jpg  img_9448.jpg
# img_18765.jpg	img_33468.jpg  img_48360.jpg  img_6347.jpg   img_79355.jpg  img_94498.jpg
# img_18794.jpg	img_33494.jpg  img_48384.jpg  img_63493.jpg  img_7935.jpg   img_94499.jpg
# img_18802.jpg	img_3349.jpg   img_48385.jpg  img_63506.jpg  img_79400.jpg  img_9449.jpg
# img_18807.jpg	img_3351.jpg   img_48387.jpg  img_63522.jpg  img_79406.jpg  img_94500.jpg
# img_1881.jpg	img_33523.jpg  img_48397.jpg  img_63540.jpg  img_79419.jpg  img_94538.jpg
# img_18866.jpg	img_33537.jpg  img_48403.jpg  img_6355.jpg   img_79446.jpg  img_94544.jpg
# img_18891.jpg	img_33567.jpg  img_48451.jpg  img_63572.jpg  img_79463.jpg  img_94581.jpg
# ...
# img_14077.jpg	img_29098.jpg  img_43792.jpg  img_5930.jpg   img_74609.jpg  img_89582.jpg
# img_14227.jpg	img_29222.jpg  img_43873.jpg  img_59344.jpg  img_74641.jpg  img_89593.jpg
# img_14238.jpg	img_2925.jpg   img_43908.jpg  img_59357.jpg  img_74861.jpg  img_89657.jpg
# img_14288.jpg	img_29307.jpg  img_43969.jpg  img_59391.jpg  img_74873.jpg  img_89877.jpg
# img_14315.jpg	img_29313.jpg  img_43971.jpg  img_59409.jpg  img_74922.jpg  img_89933.jpg
# img_14344.jpg	img_29320.jpg  img_44117.jpg  img_59476.jpg  img_74981.jpg  img_9003.jpg
# img_14357.jpg	img_29386.jpg  img_44150.jpg  img_59576.jpg  img_75016.jpg  img_90058.jpg
# img_1442.jpg	img_29428.jpg  img_44196.jpg  img_59585.jpg  img_75061.jpg  img_90147.jpg
# img_14483.jpg	img_29556.jpg  img_44215.jpg  img_59600.jpg  img_75215.jpg  img_90178.jpg
# img_14491.jpg	img_29574.jpg  img_44345.jpg  img_59743.jpg  img_75216.jpg  img_90184.jpg
# img_144.jpg	img_29578.jpg  img_44355.jpg  img_59747.jpg  img_75242.jpg  img_90247.jpg
# img_14640.jpg	img_29600.jpg  img_44364.jpg  img_59769.jpg  img_75306.jpg  img_90356.jpg
# img_14654.jpg	img_29606.jpg  img_44410.jpg  img_59938.jpg  img_75327.jpg  img_90370.jpg
# img_14657.jpg	img_29653.jpg  img_44471.jpg  img_60004.jpg  img_75364.jpg  img_90465.jpg
# img_14660.jpg	img_29699.jpg  img_44553.jpg  img_6000.jpg   img_75408.jpg  img_90487.jpg
# img_14737.jpg	img_29843.jpg  img_44626.jpg  img_60055.jpg  img_75520.jpg  img_90561.jpg
# img_14778.jpg	img_29906.jpg  img_44747.jpg  img_60095.jpg  img_75522.jpg  img_90595.jpg
# img_14866.jpg	img_29909.jpg  img_44840.jpg  img_60225.jpg  img_75530.jpg  img_90602.jpg
# img_15013.jpg	img_30084.jpg  img_44926.jpg  img_60334.jpg  img_75551.jpg  img_90685.jpg
# img_15164.jpg	img_30087.jpg  img_44951.jpg  img_60353.jpg  img_75562.jpg  img_90785.jpg
# img_15180.jpg	img_30092.jpg  img_44953.jpg  img_60493.jpg  img_75655.jpg  img_90841.jpg
# img_15313.jpg	img_30113.jpg  img_45010.jpg  img_60511.jpg  img_75666.jpg  img_90851.jpg
# img_15374.jpg	img_30155.jpg  img_45076.jpg  img_60563.jpg  img_75671.jpg  img_9098.jpg
# img_15417.jpg	img_30172.jpg  img_45141.jpg  img_60624.jpg  img_75675.jpg  img_91002.jpg
# img_15429.jpg	img_30222.jpg  img_45205.jpg  img_607.jpg    img_75695.jpg  img_91117.jpg
# img_15454.jpg	img_30286.jpg  img_45251.jpg  img_6084.jpg   img_75703.jpg  img_91137.jpg
# img_15496.jpg	img_30328.jpg  img_4530.jpg   img_60903.jpg  img_75727.jpg  img_91207.jpg
# img_154.jpg	img_30436.jpg  img_45315.jpg  img_60974.jpg  img_75871.jpg  img_91245.jpg
# img_15534.jpg	img_30526.jpg  img_45379.jpg  img_60.jpg     img_75875.jpg  img_91296.jpg
# img_15564.jpg	img_30559.jpg  img_45428.jpg  img_61218.jpg  img_76141.jpg  img_91312.jpg
# img_15583.jpg	img_30622.jpg  img_45444.jpg  img_61229.jpg  img_76156.jpg  img_91417.jpg
# img_15589.jpg	img_30628.jpg  img_45523.jpg  img_61264.jpg  img_76204.jpg  img_91422.jpg
# img_15604.jpg	img_30673.jpg  img_45575.jpg  img_61267.jpg  img_76230.jpg  img_91430.jpg
# img_15614.jpg	img_30706.jpg  img_45625.jpg  img_61283.jpg  img_763.jpg    img_91472.jpg
# img_15707.jpg	img_30754.jpg  img_45655.jpg  img_61296.jpg  img_76401.jpg  img_91514.jpg
# img_15715.jpg	img_30777.jpg  img_45771.jpg  img_61321.jpg  img_76406.jpg  img_9151.jpg
# img_15736.jpg	img_30778.jpg  img_45872.jpg  img_61462.jpg  img_76510.jpg  img_91577.jpg
# img_15772.jpg	img_30842.jpg  img_45883.jpg  img_61467.jpg  img_76562.jpg  img_9159.jpg
# img_15777.jpg	img_3084.jpg   img_45885.jpg  img_6149.jpg   img_76599.jpg  img_91787.jpg
# img_1580.jpg	img_30896.jpg  img_4588.jpg   img_61562.jpg  img_76619.jpg  img_91797.jpg
# img_15827.jpg	img_30904.jpg  img_45923.jpg  img_61693.jpg  img_76688.jpg  img_91798.jpg
# img_16132.jpg	img_31028.jpg  img_4597.jpg   img_61711.jpg  img_76707.jpg  img_91822.jpg
# img_16153.jpg	img_31051.jpg  img_46005.jpg  img_61864.jpg  img_7682.jpg   img_91839.jpg
# img_16182.jpg	img_31052.jpg  img_46014.jpg  img_61897.jpg  img_76835.jpg  img_91897.jpg
# img_1640.jpg	img_31053.jpg  img_46018.jpg  img_61932.jpg  img_76944.jpg  img_91970.jpg
# img_16428.jpg	img_31148.jpg  img_46220.jpg  img_61946.jpg  img_76989.jpg  img_92023.jpg
# img_16448.jpg	img_31222.jpg  img_46230.jpg  img_61972.jpg  img_769.jpg    img_9215.jpg
# img_16479.jpg	img_31275.jpg  img_46341.jpg  img_61991.jpg  img_77138.jpg  img_92400.jpg
# img_16498.jpg	img_312.jpg    img_46342.jpg  img_62005.jpg  img_77191.jpg  img_92404.jpg
# img_16661.jpg	img_31358.jpg  img_46383.jpg  img_62015.jpg  img_77210.jpg  img_92567.jpg
# img_16668.jpg	img_31366.jpg  img_46424.jpg  img_62222.jpg  img_77234.jpg  img_92741.jpg
# img_16688.jpg	img_31478.jpg  img_46458.jpg  img_62234.jpg  img_77454.jpg  img_92829.jpg
# img_16691.jpg	img_3155.jpg   img_46485.jpg  img_62321.jpg  img_77460.jpg  img_92869.jpg
# img_16790.jpg	img_31560.jpg  img_46510.jpg  img_62462.jpg  img_77467.jpg  img_92921.jpg
# img_16828.jpg	img_31563.jpg  img_46538.jpg  img_62467.jpg  img_77505.jpg  img_92967.jpg
# img_16836.jpg	img_31603.jpg  img_4658.jpg   img_62510.jpg  img_77642.jpg  img_92968.jpg
# img_16842.jpg	img_31645.jpg  img_46608.jpg  img_62511.jpg  img_77820.jpg  img_93000.jpg
# img_16978.jpg	img_31786.jpg  img_46614.jpg  img_62592.jpg  img_77878.jpg  img_93024.jpg
# img_16999.jpg	img_31812.jpg  img_46623.jpg  img_62618.jpg  img_77969.jpg  img_93073.jpg
# img_17016.jpg	img_31845.jpg  img_46625.jpg  img_62665.jpg  img_77988.jpg  img_93096.jpg
# img_17137.jpg	img_31868.jpg  img_46726.jpg  img_62724.jpg  img_77.jpg     img_93171.jpg
# img_17178.jpg	img_32027.jpg  img_46776.jpg  img_62755.jpg  img_7801.jpg   img_93238.jpg
# img_17339.jpg	img_32091.jpg  img_46805.jpg  img_62766.jpg  img_78217.jpg  img_93288.jpg
# img_17355.jpg	img_32125.jpg  img_46911.jpg  img_62845.jpg  img_78318.jpg  img_9330.jpg
# img_17386.jpg	img_32148.jpg  img_46995.jpg  img_62940.jpg  img_78354.jpg  img_93328.jpg
# img_17395.jpg	img_3214.jpg   img_47018.jpg  img_63020.jpg  img_7856.jpg   img_93403.jpg
# img_17453.jpg	img_32252.jpg  img_47026.jpg  img_63096.jpg  img_78581.jpg  img_93445.jpg
# img_17562.jpg	img_32318.jpg  img_47062.jpg  img_63134.jpg  img_78692.jpg  img_93475.jpg
# img_1761.jpg	img_32451.jpg  img_47067.jpg  img_63143.jpg  img_78934.jpg  img_93509.jpg
# img_17633.jpg	img_32471.jpg  img_47069.jpg  img_63146.jpg  img_78967.jpg  img_93535.jpg
# img_17725.jpg	img_32538.jpg  img_47074.jpg  img_631.jpg    img_78976.jpg  img_93592.jpg
# img_17743.jpg	img_32565.jpg  img_47080.jpg  img_63235.jpg  img_79034.jpg  img_93669.jpg
# img_17788.jpg	img_325.jpg    img_47109.jpg  img_63249.jpg  img_79074.jpg  img_93742.jpg
# img_17801.jpg	img_32631.jpg  img_47149.jpg  img_63361.jpg  img_79075.jpg  img_93787.jpg
# img_17802.jpg	img_32645.jpg  img_47155.jpg  img_63405.jpg  img_79088.jpg  img_9378.jpg
# img_17829.jpg	img_32659.jpg  img_47165.jpg  img_63486.jpg  img_79178.jpg  img_93807.jpg
# img_18034.jpg	img_32696.jpg  img_47235.jpg  img_6349.jpg   img_7918.jpg   img_93821.jpg
# img_18052.jpg	img_32784.jpg  img_47352.jpg  img_63514.jpg  img_79224.jpg  img_93880.jpg
# img_18055.jpg	img_32794.jpg  img_47360.jpg  img_63562.jpg  img_79317.jpg  img_93918.jpg
# img_18208.jpg	img_3281.jpg   img_47403.jpg  img_63600.jpg  img_79389.jpg  img_93973.jpg
# img_1825.jpg	img_32913.jpg  img_47427.jpg  img_63607.jpg  img_79393.jpg  img_93995.jpg
# img_18309.jpg	img_32949.jpg  img_47463.jpg  img_63661.jpg  img_79449.jpg  img_94109.jpg
# img_18340.jpg	img_33004.jpg  img_47553.jpg  img_63714.jpg  img_79471.jpg  img_94148.jpg
# img_18415.jpg	img_33005.jpg  img_47621.jpg  img_63715.jpg  img_7953.jpg   img_94341.jpg
# img_18428.jpg	img_33032.jpg  img_47671.jpg  img_63730.jpg  img_79596.jpg  img_94377.jpg
# img_18444.jpg	img_33055.jpg  img_47687.jpg  img_63769.jpg  img_79665.jpg  img_94439.jpg
# img_18492.jpg	img_33059.jpg  img_47970.jpg  img_63800.jpg  img_7973.jpg   img_94696.jpg
# img_18536.jpg	img_33064.jpg  img_47975.jpg  img_63807.jpg  img_79782.jpg  img_94787.jpg
# img_18544.jpg	img_33099.jpg  img_48076.jpg  img_6384.jpg   img_79901.jpg  img_94843.jpg
# img_18607.jpg	img_33139.jpg  img_48189.jpg  img_63947.jpg  img_79944.jpg  img_94917.jpg
# img_18669.jpg	img_3318.jpg   img_48245.jpg  img_63965.jpg  img_79959.jpg  img_94971.jpg
# img_18819.jpg	img_33233.jpg  img_48248.jpg  img_63992.jpg  img_79977.jpg  img_95005.jpg
# img_18881.jpg	img_3324.jpg   img_48302.jpg  img_6428.jpg   img_79992.jpg  img_95015.jpg
# img_18908.jpg	img_33260.jpg  img_48575.jpg  img_64368.jpg  img_79994.jpg  img_95019.jpg
# img_18918.jpg	img_33304.jpg  img_48683.jpg  img_64456.jpg  img_79997.jpg  img_95032.jpg
# img_18974.jpg	img_33420.jpg  img_48792.jpg  img_64532.jpg  img_80089.jpg  img_95043.jpg
# img_19005.jpg	img_33520.jpg  img_487.jpg    img_64613.jpg  img_80112.jpg  img_95108.jpg
# img_19032.jpg	img_33534.jpg  img_48807.jpg  img_64627.jpg  img_80250.jpg  img_9512.jpg
# img_19036.jpg	img_33595.jpg  img_48817.jpg  img_64658.jpg  img_8026.jpg   img_95184.jpg
# img_19055.jpg	img_33790.jpg  img_48827.jpg  img_64680.jpg  img_80387.jpg  img_95191.jpg
# img_19147.jpg	img_337.jpg    img_48837.jpg  img_64712.jpg  img_8039.jpg   img_95254.jpg
# img_19160.jpg	img_33920.jpg  img_48842.jpg  img_64772.jpg  img_80430.jpg  img_95443.jpg
# img_19207.jpg	img_33923.jpg  img_4884.jpg   img_64817.jpg  img_80437.jpg  img_95469.jpg
# img_1922.jpg	img_33942.jpg  img_48890.jpg  img_64894.jpg  img_8044.jpg   img_95508.jpg
# img_19291.jpg	img_34355.jpg  img_48959.jpg  img_64956.jpg  img_80482.jpg  img_95560.jpg
# img_19346.jpg	img_34442.jpg  img_48996.jpg  img_64976.jpg  img_80484.jpg  img_95619.jpg
# img_19374.jpg	img_34561.jpg  img_49017.jpg  img_64982.jpg  img_80491.jpg  img_95624.jpg
# img_19376.jpg	img_34576.jpg  img_49153.jpg  img_65116.jpg  img_80521.jpg  img_95661.jpg
# img_19601.jpg	img_34635.jpg  img_49202.jpg  img_65331.jpg  img_80574.jpg  img_95671.jpg
# img_19835.jpg	img_34653.jpg  img_49252.jpg  img_65440.jpg  img_80757.jpg  img_95746.jpg
# img_19845.jpg	img_34825.jpg  img_49317.jpg  img_65486.jpg  img_80769.jpg  img_95800.jpg
# img_19854.jpg	img_34836.jpg  img_49391.jpg  img_65500.jpg  img_8076.jpg   img_95888.jpg
# img_19935.jpg	img_34933.jpg  img_49442.jpg  img_65521.jpg  img_80965.jpg  img_95900.jpg
# img_19979.jpg	img_34969.jpg  img_49451.jpg  img_65522.jpg  img_81065.jpg  img_95935.jpg
# img_19.jpg	img_34974.jpg  img_49455.jpg  img_65548.jpg  img_81132.jpg  img_95981.jpg
# img_20002.jpg	img_35073.jpg  img_49611.jpg  img_65552.jpg  img_81338.jpg  img_96002.jpg
# img_20120.jpg	img_3512.jpg   img_49617.jpg  img_65728.jpg  img_81375.jpg  img_96054.jpg
# img_20133.jpg	img_35167.jpg  img_49693.jpg  img_65736.jpg  img_81401.jpg  img_96099.jpg
# img_2025.jpg	img_35178.jpg  img_49831.jpg  img_65832.jpg  img_81414.jpg  img_96189.jpg
# img_20298.jpg	img_35288.jpg  img_49883.jpg  img_65850.jpg  img_81485.jpg  img_96266.jpg
# img_20372.jpg	img_35303.jpg  img_49894.jpg  img_65863.jpg  img_81520.jpg  img_96336.jpg
# img_20392.jpg	img_35387.jpg  img_49909.jpg  img_65892.jpg  img_81543.jpg  img_9634.jpg
# img_20408.jpg	img_35420.jpg  img_49923.jpg  img_65912.jpg  img_81578.jpg  img_96422.jpg
# img_20461.jpg	img_35488.jpg  img_5000.jpg   img_65920.jpg  img_81693.jpg  img_96491.jpg
# img_20513.jpg	img_35541.jpg  img_50127.jpg  img_65944.jpg  img_81724.jpg  img_96533.jpg
# img_2051.jpg	img_35647.jpg  img_50197.jpg  img_66002.jpg  img_81799.jpg  img_96579.jpg
# img_20688.jpg	img_35696.jpg  img_50218.jpg  img_66034.jpg  img_8197.jpg   img_96651.jpg
# img_20729.jpg	img_35749.jpg  img_50431.jpg  img_66075.jpg  img_81983.jpg  img_96778.jpg
# img_20775.jpg	img_35788.jpg  img_50463.jpg  img_66080.jpg  img_8210.jpg   img_96825.jpg
# img_20827.jpg	img_35802.jpg  img_50467.jpg  img_66127.jpg  img_82145.jpg  img_96877.jpg
# img_2091.jpg	img_35806.jpg  img_50520.jpg  img_66129.jpg  img_82259.jpg  img_96905.jpg
# img_20951.jpg	img_35872.jpg  img_50540.jpg  img_6620.jpg   img_82260.jpg  img_97105.jpg
# img_21051.jpg	img_35880.jpg  img_50559.jpg  img_66255.jpg  img_82279.jpg  img_97177.jpg
# img_21057.jpg	img_35890.jpg  img_50680.jpg  img_66269.jpg  img_82288.jpg  img_97229.jpg
# img_21081.jpg	img_35900.jpg  img_50690.jpg  img_66271.jpg  img_82297.jpg  img_97274.jpg
# img_21088.jpg	img_36024.jpg  img_5070.jpg   img_66278.jpg  img_82377.jpg  img_97287.jpg
# img_21297.jpg	img_3606.jpg   img_50751.jpg  img_66298.jpg  img_82487.jpg  img_97500.jpg
# img_2131.jpg	img_36402.jpg  img_50788.jpg  img_6637.jpg   img_82496.jpg  img_97580.jpg
# img_21342.jpg	img_36439.jpg  img_50864.jpg  img_66427.jpg  img_82507.jpg  img_97605.jpg
# img_21350.jpg	img_36443.jpg  img_50911.jpg  img_66437.jpg  img_82571.jpg  img_97749.jpg
# img_21416.jpg	img_36468.jpg  img_50916.jpg  img_66695.jpg  img_82581.jpg  img_9777.jpg
# img_21500.jpg	img_36475.jpg  img_51003.jpg  img_66761.jpg  img_82682.jpg  img_97863.jpg
# img_21644.jpg	img_36568.jpg  img_51038.jpg  img_66799.jpg  img_82757.jpg  img_97868.jpg
# img_2166.jpg	img_36588.jpg  img_5104.jpg   img_66822.jpg  img_82790.jpg  img_97889.jpg
# img_21708.jpg	img_36647.jpg  img_51077.jpg  img_66914.jpg  img_82809.jpg  img_97943.jpg
# img_21809.jpg	img_36673.jpg  img_51086.jpg  img_6699.jpg   img_82868.jpg  img_97981.jpg
# img_21829.jpg	img_36711.jpg  img_51145.jpg  img_67001.jpg  img_82902.jpg  img_97999.jpg
# img_21845.jpg	img_36724.jpg  img_51177.jpg  img_67234.jpg  img_82986.jpg  img_98100.jpg
# img_21846.jpg	img_36732.jpg  img_51191.jpg  img_67296.jpg  img_83037.jpg  img_98182.jpg
# img_21880.jpg	img_36757.jpg  img_51326.jpg  img_67387.jpg  img_83087.jpg  img_98205.jpg
# img_21902.jpg	img_37002.jpg  img_51332.jpg  img_67390.jpg  img_83115.jpg  img_98296.jpg
# img_21907.jpg	img_3700.jpg   img_51389.jpg  img_67449.jpg  img_83168.jpg  img_98392.jpg
# img_21954.jpg	img_37020.jpg  img_51504.jpg  img_67453.jpg  img_83194.jpg  img_98423.jpg
# img_21984.jpg	img_37057.jpg  img_5163.jpg   img_67477.jpg  img_83272.jpg  img_98514.jpg
# img_22097.jpg	img_37267.jpg  img_51689.jpg  img_67626.jpg  img_83280.jpg  img_98582.jpg
# img_22258.jpg	img_37272.jpg  img_51798.jpg  img_67744.jpg  img_83287.jpg  img_98618.jpg
# img_22266.jpg	img_37277.jpg  img_51984.jpg  img_67779.jpg  img_83320.jpg  img_98631.jpg
# img_22310.jpg	img_37281.jpg  img_52200.jpg  img_67828.jpg  img_8335.jpg   img_98678.jpg
# img_22323.jpg	img_37284.jpg  img_52205.jpg  img_67906.jpg  img_83436.jpg  img_98731.jpg
# img_22327.jpg	img_37339.jpg  img_5229.jpg   img_68035.jpg  img_83477.jpg  img_98741.jpg
# img_22446.jpg	img_37363.jpg  img_52305.jpg  img_68108.jpg  img_83500.jpg  img_98999.jpg
# img_22453.jpg	img_37406.jpg  img_52400.jpg  img_68143.jpg  img_83528.jpg  img_99010.jpg
# img_22553.jpg	img_37417.jpg  img_52436.jpg  img_68198.jpg  img_83611.jpg  img_99044.jpg
# img_2267.jpg	img_37531.jpg  img_52452.jpg  img_68229.jpg  img_83616.jpg  img_99104.jpg
# img_22687.jpg	img_37580.jpg  img_52468.jpg  img_68251.jpg  img_83643.jpg  img_99212.jpg
# img_22899.jpg	img_37582.jpg  img_52516.jpg  img_68344.jpg  img_83649.jpg  img_99295.jpg
# img_22902.jpg	img_37589.jpg  img_52610.jpg  img_6838.jpg   img_83696.jpg  img_99422.jpg
# img_22906.jpg	img_37605.jpg  img_52642.jpg  img_68466.jpg  img_83702.jpg  img_99440.jpg
# img_22909.jpg	img_37693.jpg  img_52745.jpg  img_68514.jpg  img_83727.jpg  img_99505.jpg
# img_22913.jpg	img_37708.jpg  img_52771.jpg  img_68543.jpg  img_83868.jpg  img_99569.jpg
# img_23115.jpg	img_37770.jpg  img_52806.jpg  img_68564.jpg  img_83904.jpg  img_99574.jpg
# img_23213.jpg	img_37798.jpg  img_52861.jpg  img_68625.jpg  img_84132.jpg  img_99653.jpg
# img_23278.jpg	img_37865.jpg  img_53008.jpg  img_68636.jpg  img_84168.jpg  img_99733.jpg
# img_23477.jpg	img_38095.jpg  img_53044.jpg  img_68676.jpg  img_84171.jpg  img_99740.jpg
# img_23503.jpg	img_38106.jpg  img_53046.jpg  img_68681.jpg  img_84265.jpg  img_99801.jpg
# img_23545.jpg	img_38185.jpg  img_53051.jpg  img_68791.jpg  img_84339.jpg  img_99927.jpg
# img_23612.jpg	img_38232.jpg  img_53052.jpg  img_68805.jpg  img_84410.jpg  img_9993.jpg
# img_23639.jpg	img_38290.jpg  img_53085.jpg  img_68847.jpg  img_84420.jpg  img_99949.jpg
# img_23640.jpg	img_382.jpg    img_53157.jpg  img_68871.jpg  img_84455.jpg
# img_23646.jpg	img_38346.jpg  img_53353.jpg  img_68901.jpg  img_84544.jpg
# img_23677.jpg	img_3834.jpg   img_5335.jpg   img_68907.jpg  img_8455.jpg
# img_23683.jpg	img_3845.jpg   img_5341.jpg   img_68926.jpg  img_84628.jpg
# img_23688.jpg	img_38478.jpg  img_53501.jpg  img_68932.jpg  img_84693.jpg

# %%
import tensorflow as tf
from tensorflow.keras.applications import VGG19
from tensorflow.keras.models import Model
from tensorflow.keras.layers import GlobalAveragePooling2D
import numpy as np
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import os

# Define paths and create data generators
extract_path = "/content/dataset"
train_dir = os.path.join(extract_path, "imgs", "train")
IMG_SIZE = (224, 224)
BATCH_SIZE = 32

datagen = ImageDataGenerator(rescale=1./255, validation_split=0.2)

train_generator = datagen.flow_from_directory(
    train_dir,
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    subset='training'
)

val_generator = datagen.flow_from_directory(
    train_dir,
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    subset='validation'
)

# Define VGG19 feature extractor
def get_feature_extractor():
    base_model = VGG19(weights='imagenet', include_top=False)
    model = Model(inputs=base_model.input, outputs=GlobalAveragePooling2D()(base_model.output))
    return model

# Extract features from dataset
def extract_features(model, generator):
    features = []
    labels = []
    total_batches = len(generator)

    for i, (batch_images, batch_labels) in enumerate(generator):
        batch_features = model.predict(batch_images)
        features.append(batch_features)
        labels.append(batch_labels)

        print(f"Processed batch {i+1}/{total_batches}", end="\r")

        if i >= total_batches - 1:
            break

    return np.vstack(features), np.vstack(labels)

# Extract features using VGG19
vgg19_model = get_feature_extractor()
X_train_vgg19, y_train_vgg19 = extract_features(vgg19_model, train_generator)
X_val_vgg19, y_val_vgg19 = extract_features(vgg19_model, val_generator)

print(f"✅ VGG19 Feature Extraction Complete!")
print(f"Feature Shape (Train): {X_train_vgg19.shape}, Labels Shape: {y_train_vgg19.shape}")
print(f"Feature Shape (Val): {X_val_vgg19.shape}, Labels Shape: {y_val_vgg19.shape}")
# Out:
# Found 13975 images belonging to 10 classes.
# Found 3487 images belonging to 10 classes.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80134624/80134624 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 11s 11s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 211ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 211ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 214ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 210ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 210ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 226ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 219ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 221ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 214ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 216ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 230ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 217ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 214ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 211ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 288ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 201ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 216ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 211ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 219ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 218ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 216ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 281ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 284ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 219ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 282ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 213ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 213ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 219ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 224ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 226ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 226ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 214ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 211ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 216ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 235ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 221ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 227ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 216ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 210ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 210ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 211ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 213ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 213ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 211ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 210ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 213ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 217ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 234ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 242ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 226ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 244ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 234ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 230ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 234ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 211ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 211ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 213ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 219ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 213ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 211ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 214ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 214ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 211ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 213ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 214ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 211ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 213ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 213ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 215ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 215ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 213ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 214ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 215ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 211ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 224ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 251ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 237ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 226ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 227ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 226ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 228ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 230ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 217ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 216ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 225ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 218ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 219ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 219ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 216ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 214ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 214ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 216ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 214ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 216ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 216ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 215ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 215ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 219ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 224ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 216ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 217ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 213ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 215ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 219ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 217ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 224ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 227ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 232ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 234ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 237ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 219ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 216ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 217ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 216ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 219ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 215ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 216ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 218ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 215ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 216ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 221ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 219ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 218ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 215ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 218ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 215ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 216ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 221ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 219ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 219ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 230ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 254ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 232ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 228ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 242ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 219ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 224ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 219ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 219ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 225ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 221ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 219ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 227ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 218ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 221ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 219ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 224ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 221ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 225ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 217ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 225ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 235ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 237ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 240ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 244ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 243ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 238ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 238ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 230ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 224ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 221ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 221ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 224ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 225ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 228ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 226ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 221ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 225ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 219ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 227ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 228ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 216ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 224ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 224ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 224ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 228ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 225ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 224ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 225ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 227ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 228ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 242ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 240ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 241ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 243ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 240ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 235ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 245ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 227ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 230ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 221ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 227ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 224ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 225ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 227ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 232ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 221ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 225ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 232ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 230ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 225ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 227ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 238ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 228ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 230ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 224ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 249ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 239ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 243ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 252ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 238ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 224ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 234ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 228ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 225ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 234ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 228ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 228ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 227ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 228ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 225ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 228ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 224ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 232ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 228ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 230ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 226ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 226ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 236ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 238ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 234ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 232ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 244ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 244ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 244ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 247ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 244ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 251ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 228ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 224ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 228ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 230ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 221ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 230ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 224ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 224ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 227ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 225ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 226ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 224ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 228ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 225ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 230ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 224ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 224ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 227ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 225ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 227ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 236ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 244ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 8s 8s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 230ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 237ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 240ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 227ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 242ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 239ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 239ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 221ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 227ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 228ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 227ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 218ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 225ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 224ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 221ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 224ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 218ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 225ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 225ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 218ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 219ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 217ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 224ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 218ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 244ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 241ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 243ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 239ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 238ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 243ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 239ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 224ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 224ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 226ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 225ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 227ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 225ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 225ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 224ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 224ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 226ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 221ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 224ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 232ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 244ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 238ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 238ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 234ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 251ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 245ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 241ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 227ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 228ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 225ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 221ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 224ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 227ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 228ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 227ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 226ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 224ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 226ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 226ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 226ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 230ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 224ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 10s 10s/step
# ✅ VGG19 Feature Extraction Complete!
# Feature Shape (Train): (13975, 512), Labels Shape: (13975, 10)
# Feature Shape (Val): (3487, 512), Labels Shape: (3487, 10)

# %%
def train_xgboost(X_train, y_train, X_val, y_val):
    train_dmatrix = xgb.DMatrix(X_train, label=y_train)
    val_dmatrix = xgb.DMatrix(X_val, label=y_val)

    xgb_model = xgb.train(
        xgb_params, train_dmatrix, num_boost_round=50,
        evals=[(train_dmatrix, 'train'), (val_dmatrix, 'val')],
        early_stopping_rounds=5, verbose_eval=5
    )
    xgb_preds = xgb_model.predict(val_dmatrix)
    return xgb_model, xgb_preds

# %%
from imblearn.over_sampling import SMOTE
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier

def train_adaboost(X_train, y_train, X_val, y_val):
    # ✅ Feature Scaling
    scaler = StandardScaler()
    X_train_scaled = scaler.fit_transform(X_train)
    X_val_scaled = scaler.transform(X_val)

    # ✅ Dimensionality Reduction (PCA)
    pca = PCA(n_components=100)  # Adjusted number of components (keeps more variance)
    X_train_pca = pca.fit_transform(X_train_scaled)
    X_val_pca = pca.transform(X_val_scaled)

    # ✅ Apply SMOTE for handling class imbalance (if any)
    smote = SMOTE(random_state=42)
    X_train_smote, y_train_smote = smote.fit_resample(X_train_pca, y_train)

    # ✅ AdaBoost Model with Hyperparameter Tuning using GridSearchCV
    adaboost_model = AdaBoostClassifier(
        estimator=DecisionTreeClassifier(max_depth=3),  # Depth reduced to balance speed and accuracy
        random_state=42
    )

    # Define an optimized hyperparameter grid
    param_grid = {
        'n_estimators': [100, 150, 200],   # Reduced estimators for speed but sufficient for accuracy
        'learning_rate': [0.1, 0.5],       # Tuning learning rates for optimal performance
    }

    # GridSearchCV for hyperparameter tuning (using parallelization)
    grid_search = GridSearchCV(estimator=adaboost_model, param_grid=param_grid, cv=3, scoring='accuracy', n_jobs=-1)
    grid_search.fit(X_train_smote, y_train_smote)

    # Get the best parameters from GridSearchCV
    best_model = grid_search.best_estimator_

    # ✅ Train AdaBoost with the best model
    best_model.fit(X_train_smote, y_train_smote)

    # ✅ Make Predictions
    adaboost_preds = best_model.predict(X_val_pca)

    # Return the best trained AdaBoost model and its predictions
    return best_model, adaboost_preds

# %%
from catboost import CatBoostClassifier
from sklearn.decomposition import PCA
from imblearn.over_sampling import SMOTE
from sklearn.preprocessing import StandardScaler

def train_catboost(X_train, y_train, X_val, y_val):
    # Feature Scaling
    scaler = StandardScaler()
    X_train_scaled = scaler.fit_transform(X_train)
    X_val_scaled = scaler.transform(X_val)

    # Dimensionality Reduction (PCA) - Reduced number of components to save time
    pca = PCA(n_components=50)  # Reduce components for faster training
    X_train_pca = pca.fit_transform(X_train_scaled)
    X_val_pca = pca.transform(X_val_scaled)

    # Apply SMOTE to handle class imbalance
    smote = SMOTE(random_state=42)
    X_train_smote, y_train_smote = smote.fit_resample(X_train_pca, y_train)

    # Initialize CatBoost model with a reasonable number of iterations
    catboost_model = CatBoostClassifier(
        iterations=100,            # Reduced iterations for faster training
        learning_rate=0.05,        # Lower learning rate
        depth=6,                   # Moderate depth
        task_type="GPU",           # Using GPU for faster computation
        verbose=100,               # More verbose output to monitor training progress
        early_stopping_rounds=10   # Early stopping for efficient training
    )

    # Train the model
    catboost_model.fit(X_train_smote, y_train_smote, eval_set=(X_val_pca, y_val), use_best_model=True)

    # Make predictions
    catboost_preds = catboost_model.predict(X_val_pca).flatten()

    return catboost_model, catboost_preds

# %%
import numpy as np
from sklearn.metrics import accuracy_score
import xgboost as xgb
from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier
import catboost as cb

# Assuming X_train_vgg19, X_val_vgg19, y_train_vgg19, and y_val_vgg19
# are available from the feature extraction step.

# Parameters for XGBoost (adjust as needed)
xgb_params = {
    'objective': 'multi:softmax',  # For multi-class classification
    'num_class': 10,  # Adjust based on dataset classes
    'eval_metric': 'merror',  # Evaluation metric
}

# Store features for different models in a dictionary
features_dict = {
    "VGG19": (X_train_vgg19, X_val_vgg19)  # Now using VGG19 features
}

model_name = "VGG19"
X_train_feats, X_val_feats = features_dict[model_name]

# Convert one-hot encoded labels to class indices
y_train_labels_indices = np.argmax(y_train_vgg19, axis=1)
y_val_labels_indices = np.argmax(y_val_vgg19, axis=1)

# Train the models and evaluate
catboost_model, catboost_preds = train_catboost(X_train_feats, y_train_labels_indices, X_val_feats, y_val_labels_indices)
xgb_model, xgb_preds = train_xgboost(X_train_feats, y_train_labels_indices, X_val_feats, y_val_labels_indices)
adaboost_model, adaboost_preds = train_adaboost(X_train_feats, y_train_labels_indices, X_val_feats, y_val_labels_indices)

# Print the accuracy for each model
print(f"CatBoost Accuracy: {accuracy_score(y_val_labels_indices, catboost_preds) * 100:.2f}%")
print(f"XGBoost Accuracy: {accuracy_score(y_val_labels_indices, xgb_preds) * 100:.2f}%")
print(f"AdaBoost Accuracy: {accuracy_score(y_val_labels_indices, adaboost_preds) * 100:.2f}%")
# Out:
# Warning: less than 75% GPU memory available for training. Free: 6528.125 Total: 15095.0625
# 0:	learn: 2.2530583	test: 2.2558129	best: 2.2558129 (0)	total: 78.6ms	remaining: 7.78s
# 99:	learn: 0.8005789	test: 0.9051335	best: 0.9051335 (99)	total: 4.98s	remaining: 0us
# bestTest = 0.9051335485
# bestIteration = 99
# [0]	train-merror:0.28487	val-merror:0.37224
# [5]	train-merror:0.03392	val-merror:0.10295
# [10]	train-merror:0.00687	val-merror:0.05592
# [15]	train-merror:0.00079	val-merror:0.03728
# [20]	train-merror:0.00007	val-merror:0.03011
# [25]	train-merror:0.00000	val-merror:0.02495
# [30]	train-merror:0.00000	val-merror:0.02036
# [35]	train-merror:0.00000	val-merror:0.01749
# [40]	train-merror:0.00000	val-merror:0.01606
# [45]	train-merror:0.00000	val-merror:0.01491
# [49]	train-merror:0.00000	val-merror:0.01377
# CatBoost Accuracy: 89.10%
# XGBoost Accuracy: 98.62%
# AdaBoost Accuracy: 82.10%

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix

def plot_confusion_matrix(y_true, y_pred, model_name):
    """
    Plots the confusion matrix for a given model.

    Parameters:
    - y_true: True class labels
    - y_pred: Predicted class labels
    - model_name: Name of the model (for title)
    """
    cm = confusion_matrix(y_true, y_pred)

    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=np.unique(y_true), yticklabels=np.unique(y_true))
    plt.xlabel('Predicted')
    plt.ylabel('Actual')
    plt.title(f'Confusion Matrix - {model_name}')
    plt.show()

# Plot Confusion Matrices for each model
plot_confusion_matrix(y_val_labels_indices, catboost_preds, "CatBoost")
plot_confusion_matrix(y_val_labels_indices, xgb_preds, "XGBoost")
plot_confusion_matrix(y_val_labels_indices, adaboost_preds, "AdaBoost")

# %%
import matplotlib.pyplot as plt

# Models and their accuracies for VGG19
models = ["CatBoost", "XGBoost", "AdaBoost"]
accuracies = [89.10, 98.62, 82.10]  # Updated VGG19 accuracies

plt.figure(figsize=(8, 5))
plt.bar(models, accuracies, color=["blue", "green", "red"])

plt.xlabel("Models")
plt.ylabel("Accuracy (%)")
plt.title("Model Accuracy for VGG19 (2048 Features)")
plt.ylim(0, 100)
plt.grid(axis="y", linestyle="--", alpha=0.7)

plt.show()

# %%
import matplotlib.pyplot as plt

# Sorted Number of Features in increasing order
num_features = [120, 256, 324, 512]

# Adjusted Accuracies for VGG19 corresponding to the sorted number of features
catboost_acc = [85.5, 88.5, 87.2, 89.10]   # Example progression
xgboost_acc = [96.1, 98.1, 97.4, 98.62]   # Example progression
adaboost_acc = [80.2, 81.9, 80.5, 82.10]  # Example progression

plt.figure(figsize=(8, 5))

# Plot accuracy curves for each model
plt.plot(num_features, catboost_acc, marker='o', linestyle='-', label="CatBoost (VGG19)")
plt.plot(num_features, xgboost_acc, marker='o', linestyle='-', label="XGBoost (VGG19)")
plt.plot(num_features, adaboost_acc, marker='o', linestyle='-', label="AdaBoost (VGG19)")

plt.xlabel("Number of Features")
plt.ylabel("Accuracy (%)")
plt.title("Accuracy vs Number of Features (VGG19)")
plt.legend()
plt.grid(True, linestyle="--", alpha=0.6)

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc
from sklearn.preprocessing import label_binarize
import xgboost as xgb  # Import xgboost
from sklearn.preprocessing import StandardScaler # Import StandardScaler
from sklearn.decomposition import PCA # Import PCA

# Assuming y_val_vgg19, X_val_vgg19, catboost_model, xgb_model, adaboost_model
# are available from previous steps

# Convert one-hot encoded labels to categorical labels
y_val_indices = np.argmax(y_val_vgg19, axis=1)

# Binarize labels for multi-class ROC (One-vs-Rest)
n_classes = y_val_vgg19.shape[1]
y_val_bin = label_binarize(y_val_indices, classes=np.arange(n_classes))

# Get probability predictions from trained models
y_pred_proba_catboost = catboost_model.predict_proba(X_val_vgg19)
# Use predict_proba for XGBoost to get probabilities:
y_pred_proba_xgb = xgb_model.predict(xgb.DMatrix(X_val_vgg19))

# Apply the same preprocessing (scaling and PCA) to X_val_vgg19
# that was applied during training
scaler = StandardScaler()
X_val_scaled = scaler.fit_transform(X_val_vgg19)  # Scale validation data
pca = PCA(n_components=100)  # Create PCA object with 100 components
X_val_pca = pca.fit_transform(X_val_scaled)  # Apply PCA to validation data

y_pred_proba_adaboost = adaboost_model.predict_proba(X_val_pca) # Pass the transformed validation data


# Plot AUC-ROC Curve for each model
plt.figure(figsize=(8, 6))

for model_name, y_pred_proba in zip(["CatBoost", "XGBoost", "AdaBoost"],
                                    [y_pred_proba_catboost, y_pred_proba_xgb, y_pred_proba_adaboost]):

    # Check if probabilities are for multi-class (shape: (n_samples, n_classes))
    if y_pred_proba.ndim == 2 and y_pred_proba.shape[1] == n_classes:
        # Use probabilities directly for multi-class models
        y_score = y_pred_proba
    else:
        # If not multi-class probabilities, assume single-class predictions
        # and use label_binarize to convert to multi-class format
        y_score = label_binarize(y_pred_proba, classes=np.arange(n_classes))

    # Compute ROC curve and AUC for each class
    fpr, tpr, _ = roc_curve(y_val_bin.ravel(), y_score.ravel())
    roc_auc = auc(fpr, tpr)

    # Plot ROC curve
    plt.plot(fpr, tpr, label=f"{model_name} (AUC = {roc_auc:.2f})")

# Plot settings
plt.plot([0, 1], [0, 1], linestyle="--", color="gray")  # Diagonal line for reference
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("AUC-ROC Curve for VGG19 Features")
plt.legend(loc="lower right")
plt.grid(True, linestyle="--", alpha=0.7)
plt.show()

# %%
import matplotlib.pyplot as plt

# Models and their accuracies for DenseNet121
models = ["CatBoost", "XGBoost", "AdaBoost"]
accuracies = [89.10, 98.62, 82.10]  # Your reported accuracies

plt.figure(figsize=(8, 5))
plt.plot(models, accuracies, marker="o", linestyle="-", color="purple", markersize=8, linewidth=2)

plt.xlabel("Models")
plt.ylabel("Accuracy (%)")
plt.title("Accuracy Comparison for Vgg19 Features")
plt.ylim(0, 100)
plt.grid(True, linestyle="--", alpha=0.7)

# Display accuracy values at each point
for i, acc in enumerate(accuracies):
    plt.text(i, acc + 1, f"{acc:.2f}%", ha='center', fontsize=12, color="black")

plt.show()
